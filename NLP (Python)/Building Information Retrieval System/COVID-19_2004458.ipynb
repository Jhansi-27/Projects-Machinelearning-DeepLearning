# %% [markdown]
# # 1. Import the dataset and libraries

# %%
import pandas as pd
import numpy as np
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfTransformer

import warnings
warnings.filterwarnings('ignore')

# %%
# Reading metadata.csv file into pandas dataframe
covid_df = pd.read_csv("metadata\metadata.csv",low_memory=False)
covid_df.head(2)
# Out:
#    cord_uid                                       sha source_x  \
# 0  ug7v899j  d1aafb70c066a2068b02786f8929fd9c900897fb      PMC
# 1  02tnwd4m  6b0567729c2143a66d737eb0a2f63f2dce2e5a7d      PMC
#
#                                                title                    doi  \
# 0  Clinical features of culture-proven Mycoplasma...  10.1186/1471-2334-1-6
# 1  Nitric oxide: a pro-inflammatory mediator in l...           10.1186/rr14
#
#       pmcid pubmed_id license  \
# 0  PMC35282  11472636   no-cc
# 1  PMC59543  11667967   no-cc
#
#                                             abstract publish_time  \
# 0  OBJECTIVE: This retrospective chart review des...   2001-07-04
# 1  Inflammatory diseases of the respiratory tract...   2000-08-15
#
#                                              authors         journal  mag_id  \
# 0                Madani, Tariq A; Al-Ghamdi, Aisha A  BMC Infect Dis     NaN
# 1  Vliet, Albert van der; Eiserich, Jason P; Cros...      Respir Res     NaN
#
#   who_covidence_id arxiv_id  \
# 0              NaN      NaN
# 1              NaN      NaN
#
#                                       pdf_json_files  \
# 0  document_parses/pdf_json/d1aafb70c066a2068b027...
# 1  document_parses/pdf_json/6b0567729c2143a66d737...
#
#                                pmc_json_files  \
# 0  document_parses/pmc_json/PMC35282.xml.json
# 1  document_parses/pmc_json/PMC59543.xml.json
#
#                                                  url  s2_id
# 0  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...    NaN
# 1  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...    NaN

# %%
columnnames = covid_df.columns
print(columnnames)
# Out:
# Index(['cord_uid', 'sha', 'source_x', 'title', 'doi', 'pmcid', 'pubmed_id',
#        'license', 'abstract', 'publish_time', 'authors', 'journal', 'mag_id',
#        'who_covidence_id', 'arxiv_id', 'pdf_json_files', 'pmc_json_files',
#        'url', 's2_id'],
#       dtype='object')

# %%
print("shape of the dataframe : ", covid_df.shape)
# Out:
# shape of the dataframe :  (467521, 19)

# %%
covid_df.abstract[1]
# Out:
# 'Inflammatory diseases of the respiratory tract are commonly associated with elevated production of nitric oxide (NO•) and increased indices of NO• -dependent oxidative stress. Although NO• is known to have anti-microbial, anti-inflammatory and anti-oxidant properties, various lines of evidence support the contribution of NO• to lung injury in several disease models. On the basis of biochemical evidence, it is often presumed that such NO• -dependent oxidations are due to the formation of the oxidant peroxynitrite, although alternative mechanisms involving the phagocyte-derived heme proteins myeloperoxidase and eosinophil peroxidase might be operative during conditions of inflammation. Because of the overwhelming literature on NO• generation and activities in the respiratory tract, it would be beyond the scope of this commentary to review this area comprehensively. Instead, it focuses on recent evidence and concepts of the presumed contribution of NO• to inflammatory diseases of the lung.'

# %%
covid_df['authors'][0]
# Out:
# 'Madani, Tariq A; Al-Ghamdi, Aisha A'

# %% [markdown]
# # 2. Selecting Documents for indexing

# %% [markdown]
# ##  Checking for missing values

# %%
missing = covid_df.isnull().sum()
missing
# Out:
# cord_uid                 0
# sha                 313313
# source_x                 0
# title                  229
# doi                 209216
# pmcid               303497
# pubmed_id           241784
# license                  0
# abstract            129532
# publish_time           219
# authors              13303
# journal              31440
# mag_id              467521
# who_covidence_id    276110
# arxiv_id            461368
# pdf_json_files      313313
# pmc_json_files      343643
# url                 189789
# s2_id                41690
# dtype: int64

# %%
print("Total number of documents with abstract : ",len(covid_df)-missing['abstract'])
# Out:
# Total number of documents with abstract :  337989

# %%
print("Out of {} docments, {} documents have titles".format(len(covid_df),(len(covid_df)-missing['title'])))
print("{} documents donot have titles".format(missing['title']))
# Out:
# Out of 467521 docments, 467292 documents have titles
# 229 documents donot have titles

# %%
## Selecting 1300 docs to start with
docs = covid_df.head(1300)
len(docs)
# Out:
# 1300

# %%
docs.head(2)
# Out:
#    cord_uid                                       sha source_x  \
# 0  ug7v899j  d1aafb70c066a2068b02786f8929fd9c900897fb      PMC
# 1  02tnwd4m  6b0567729c2143a66d737eb0a2f63f2dce2e5a7d      PMC
#
#                                                title                    doi  \
# 0  Clinical features of culture-proven Mycoplasma...  10.1186/1471-2334-1-6
# 1  Nitric oxide: a pro-inflammatory mediator in l...           10.1186/rr14
#
#       pmcid pubmed_id license  \
# 0  PMC35282  11472636   no-cc
# 1  PMC59543  11667967   no-cc
#
#                                             abstract publish_time  \
# 0  OBJECTIVE: This retrospective chart review des...   2001-07-04
# 1  Inflammatory diseases of the respiratory tract...   2000-08-15
#
#                                              authors         journal  mag_id  \
# 0                Madani, Tariq A; Al-Ghamdi, Aisha A  BMC Infect Dis     NaN
# 1  Vliet, Albert van der; Eiserich, Jason P; Cros...      Respir Res     NaN
#
#   who_covidence_id arxiv_id  \
# 0              NaN      NaN
# 1              NaN      NaN
#
#                                       pdf_json_files  \
# 0  document_parses/pdf_json/d1aafb70c066a2068b027...
# 1  document_parses/pdf_json/6b0567729c2143a66d737...
#
#                                pmc_json_files  \
# 0  document_parses/pmc_json/PMC35282.xml.json
# 1  document_parses/pmc_json/PMC59543.xml.json
#
#                                                  url  s2_id
# 0  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...    NaN
# 1  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...    NaN

# %%
docs.isnull().sum()
# Out:
# cord_uid               0
# sha                   51
# source_x               0
# title                  0
# doi                    0
# pmcid                  0
# pubmed_id              0
# license                0
# abstract              59
# publish_time           0
# authors               20
# journal                0
# mag_id              1300
# who_covidence_id    1300
# arxiv_id            1300
# pdf_json_files        51
# pmc_json_files        46
# url                    0
# s2_id               1300
# dtype: int64

# %%
docs = docs.dropna(axis=1, how='all') # dropping the columns with all missing values
docs.columns
# Out:
# Index(['cord_uid', 'sha', 'source_x', 'title', 'doi', 'pmcid', 'pubmed_id',
#        'license', 'abstract', 'publish_time', 'authors', 'journal',
#        'pdf_json_files', 'pmc_json_files', 'url'],
#       dtype='object')

# %%
# mag_id,who_covidence_id,arxiv_id,s2_id theses columns have all missing values so those 4 columns are dropped

# %%
docs_with_abstract = np.where(docs.abstract.notnull()) # selecting rows with no abstract missing
docs = docs.iloc[docs_with_abstract]

# %%
docs_with_sha = np.where(docs.sha.notnull()) # selecting rows with no sha missing
docs = docs.iloc[docs_with_sha]

# %%
docs_with_authors = np.where(docs.authors.notnull()) # selecting rows with no author names missing
docs = docs.iloc[docs_with_authors]

# %%
docs_with_pdf_json_files = np.where(docs.pdf_json_files.notnull()) # selecting rows with no pdf_json_files missing
docs_with_pmf_json_files = np.where(docs.pmc_json_files.notnull()) # selecting rows with no pdf_json_files missing
docs = docs.iloc[docs_with_pdf_json_files]
docs = docs.iloc[docs_with_pmf_json_files]

# %%
print("Number of documents without any missing values : ",len(docs))
# Out:
# Number of documents without any missing values :  1186

# %% [markdown]
# ### Seleting first 1000 documents without any missing values for indexing

# %%
docs = docs.head(1000) # These 1000 documents are indexed using Logstash
docs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 1092
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   cord_uid        1000 non-null   object
#  1   sha             1000 non-null   object
#  2   source_x        1000 non-null   object
#  3   title           1000 non-null   object
#  4   doi             1000 non-null   object
#  5   pmcid           1000 non-null   object
#  6   pubmed_id       1000 non-null   object
#  7   license         1000 non-null   object
#  8   abstract        1000 non-null   object
#  9   publish_time    1000 non-null   object
#  10  authors         1000 non-null   object
#  11  journal         1000 non-null   object
#  12  pdf_json_files  1000 non-null   object
#  13  pmc_json_files  1000 non-null   object
#  14  url             1000 non-null   object
# dtypes: object(15)
# memory usage: 125.0+ KB

# %%
docs.tail(2)
# Out:
#       cord_uid                                       sha source_x  \
# 1091  d0bk9gu5  8437870dfb10809764da7204fd758ff3e9ee85db      PMC
# 1092  0jx6mwiw  df783d511b145a10e7f609a87392eb50799d2b2b      PMC
#
#                                                   title  \
# 1091  Dangerous liaisons: molecular basis for a synd...
# 1092  NOA36 Protein Contains a Highly Conserved Nucl...
#
#                                doi       pmcid pubmed_id license  \
# 1091      10.3389/fmicb.2013.00035  PMC3594938  23487416   cc-by
# 1092  10.1371/journal.pone.0059065  PMC3596294  23516598   cc-by
#
#                                                abstract publish_time  \
# 1091  The most severe manifestations of malaria (cau...   2013-03-12
# 1092  NOA36/ZNF330 is an evolutionarily well-preserv...   2013-03-13
#
#                                                 authors          journal  \
# 1091          Conant, Katelyn L.; Kaleeba, Johnan A. R.  Front Microbiol
# 1092  de Melo, Ivan S.; Jimenez-Nuñez, Maria D.; Igl...         PLoS One
#
#                                          pdf_json_files  \
# 1091  document_parses/pdf_json/8437870dfb10809764da7...
# 1092  document_parses/pdf_json/df783d511b145a10e7f60...
#
#                                     pmc_json_files  \
# 1091  document_parses/pmc_json/PMC3594938.xml.json
# 1092  document_parses/pmc_json/PMC3596294.xml.json
#
#                                                     url
# 1091  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...
# 1092  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...

# %%
docs.to_csv("CORD-19_1000docs.csv",index=False)

# This csv file with selected 1000 documents is indexed using elasticsearch

# %%
pd.read_csv("CORD_19_indexed.csv").head(3) # This is how the csv file looks like after indexing using Elasticseach
# Out:
#                  @timestamp  @version                   _id   _index  _score  \
# 0  2021-03-02T00:37:43.421Z         1  4Mhe8HcBhQmyCbDQi6-I  cord-19     NaN
# 1  2021-03-02T00:37:43.421Z         1  z8he8HcBhQmyCbDQjrLY  cord-19     NaN
# 2  2021-03-02T00:37:43.420Z         1  V8he8HcBhQmyCbDQi7GN  cord-19     NaN
#
#   _type                                           abstract  \
# 0  _doc  The most severe manifestations of malaria (cau...
# 1  _doc  NOA36/ZNF330 is an evolutionarily well-preserv...
# 2  _doc  Global climate change is expected to affect th...
#
#                                              authors  cord_uid  \
# 0          Conant, Katelyn L.; Kaleeba, Johnan A. R.  d0bk9gu5
# 1  de Melo, Ivan S.; Jimenez-Nuñez, Maria D.; Igl...  0jx6mwiw
# 2  CANN, K. F.; THOMAS, D. Rh.; SALMON, R. L.; WY...  exqza1kg
#
#                             doi  ...  \
# 0      10.3389/fmicb.2013.00035  ...
# 1  10.1371/journal.pone.0059065  ...
# 2     10.1017/s0950268812001653  ...
#
#                                                 path  \
# 0  C:/Users/jhans/Information Rereieval/CORD-19_1...
# 1  C:/Users/jhans/Information Rereieval/CORD-19_1...
# 2  C:/Users/jhans/Information Rereieval/CORD-19_1...
#
#                                       pdf_json_files  \
# 0  document_parses/pdf_json/8437870dfb10809764da7...
# 1  document_parses/pdf_json/df783d511b145a10e7f60...
# 2  document_parses/pdf_json/e008bb9bd16411df2029b...
#
#                                  pmc_json_files       pmcid  \
# 0  document_parses/pmc_json/PMC3594938.xml.json  PMC3594938
# 1  document_parses/pmc_json/PMC3596294.xml.json  PMC3596294
# 2  document_parses/pmc_json/PMC3594835.xml.json  PMC3594835
#
#                publish_time pubmed_id  \
# 0  2013-03-12T00:00:00.000Z  23487416
# 1  2013-03-13T00:00:00.000Z  23516598
# 2  2012-08-09T00:00:00.000Z  22877498
#
#                                         sha source_x  \
# 0  8437870dfb10809764da7204fd758ff3e9ee85db      PMC
# 1  df783d511b145a10e7f609a87392eb50799d2b2b      PMC
# 2  e008bb9bd16411df2029bfbfd2df3fef72a7e575      PMC
#
#                                                title  \
# 0  Dangerous liaisons: molecular basis for a synd...
# 1  NOA36 Protein Contains a Highly Conserved Nucl...
# 2  Extreme water-related weather events and water...
#
#                                                  url
# 0  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...
# 1  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...
# 2  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...
#
# [3 rows x 24 columns]

# %% [markdown]
# # 3. Data cleaning and text preprocessing
#
# Text preprocessing is the process of preparing or cleaning text data before encoding. <br>
# Encoding : Covert text data into numeric vector using techniques such as BagofWords, TF-IDF, Word2Vec etc.
#
# Preprocessing the raw text:
#
# - Removing all irrelevant characters (Numbers and punctuations)
# - Converting all characters into lowercase
# - remove tags
# - Tokenization
# - Removing stopwords
# - Stemming and Lemmetization
# - Removing the words having length <=2
# - Converting the list of tokens back to the string

# %%
text_before_preprocess = covid_df.title[0] + covid_df.abstract[0]
print("Text before preprocessing : ","\n")
print(text_before_preprocess,'\n')
print("length of text before preprocessing : ",len(text_before_preprocess))
# Out:
# Text before preprocessing :
#
# Clinical features of culture-proven Mycoplasma pneumoniae infections at King Abdulaziz University Hospital, Jeddah, Saudi ArabiaOBJECTIVE: This retrospective chart review describes the epidemiology and clinical features of 40 patients with culture-proven Mycoplasma pneumoniae infections at King Abdulaziz University Hospital, Jeddah, Saudi Arabia. METHODS: Patients with positive M. pneumoniae cultures from respiratory specimens from January 1997 through December 1998 were identified through the Microbiology records. Charts of patients were reviewed. RESULTS: 40 patients were identified, 33 (82.5%) of whom required admission. Most infections (92.5%) were community-acquired. The infection affected all age groups but was most common in infants (32.5%) and pre-school children (22.5%). It occurred year-round but was most common in the fall (35%) and spring (30%). More than three-quarters of patients (77.5%) had comorbidities. Twenty-four isolates (60%) were associated with pneumonia, 14 (35%) with upper respiratory tract infections, and 2 (5%) with bronchiolitis. Cough (82.5%), fever (75%), and malaise (58.8%) were the most common symptoms, and crepitations (60%), and wheezes (40%) were the most common signs. Most patients with pneumonia had crepitations (79.2%) but only 25% had bronchial breathing. Immunocompromised patients were more likely than non-immunocompromised patients to present with pneumonia (8/9 versus 16/31, P = 0.05). Of the 24 patients with pneumonia, 14 (58.3%) had uneventful recovery, 4 (16.7%) recovered following some complications, 3 (12.5%) died because of M pneumoniae infection, and 3 (12.5%) died due to underlying comorbidities. The 3 patients who died of M pneumoniae pneumonia had other comorbidities. CONCLUSION: our results were similar to published data except for the finding that infections were more common in infants and preschool children and that the mortality rate of pneumonia in patients with comorbidities was high.
#
# length of text before preprocessing :  1975

# %% [markdown]
# ## Function for data preprocessing

# %%
lemma= WordNetLemmatizer() # initializing object of WordNetLemmatizer for lemmatization
stop_words = set(stopwords.words('english')) # taking all the unique English stopwords from nltk corpus

def preprocess(text):
    text = re.sub('[^a-zA-Z]',' ',text) # removing numbers and punctuations
    text = str(text).lower()            # convert all characters into lowercase
    text = word_tokenize(text)          # tokenization 
    text = [item for item in text if item not in stop_words] # removing stopwords
    text = [lemma.lemmatize(word=w,pos='v') for w in text]   # lemmatization
    text = [i for i in text if len(i) > 2]   # removing token of length <=2
    text = ' '.join(text)                    # joining the tokens with space in between to form sentence
    
    return text

docs['text'] = docs['title'] + docs['abstract'] # combining the title and abstract column into a single column called text
docs['text'] = docs['text'].apply(lambda x: preprocess(x)) # applying the 'preprocess' function on 'text' column
docs['text'][0] # visualizing the processed text
# Out:
# 'clinical feature culture prove mycoplasma pneumoniae infections king abdulaziz university hospital jeddah saudi arabiaobjective retrospective chart review describe epidemiology clinical feature patients culture prove mycoplasma pneumoniae infections king abdulaziz university hospital jeddah saudi arabia methods patients positive pneumoniae culture respiratory specimens january december identify microbiology record chart patients review result patients identify require admission infections community acquire infection affect age group common infants pre school children occur year round common fall spring three quarter patients comorbidities twenty four isolate associate pneumonia upper respiratory tract infections bronchiolitis cough fever malaise common symptoms crepitations wheeze common sign patients pneumonia crepitations bronchial breathe immunocompromised patients likely non immunocompromised patients present pneumonia versus patients pneumonia uneventful recovery recover follow complications die pneumoniae infection die due underlie comorbidities patients die pneumoniae pneumonia comorbidities conclusion result similar publish data except find infections common infants preschool children mortality rate pneumonia patients comorbidities high'

# %%
print("Text after preprocessing : ","\n")
print(docs['text'][0],'\n')
print("length of text after preprocessing : ",len(docs['text'][0]))
# Out:
# Text after preprocessing :
#
# clinical feature culture prove mycoplasma pneumoniae infections king abdulaziz university hospital jeddah saudi arabiaobjective retrospective chart review describe epidemiology clinical feature patients culture prove mycoplasma pneumoniae infections king abdulaziz university hospital jeddah saudi arabia methods patients positive pneumoniae culture respiratory specimens january december identify microbiology record chart patients review result patients identify require admission infections community acquire infection affect age group common infants pre school children occur year round common fall spring three quarter patients comorbidities twenty four isolate associate pneumonia upper respiratory tract infections bronchiolitis cough fever malaise common symptoms crepitations wheeze common sign patients pneumonia crepitations bronchial breathe immunocompromised patients likely non immunocompromised patients present pneumonia versus patients pneumonia uneventful recovery recover follow complications die pneumoniae infection die due underlie comorbidities patients die pneumoniae pneumonia comorbidities conclusion result similar publish data except find infections common infants preschool children mortality rate pneumonia patients comorbidities high
#
# length of text after preprocessing :  1264

# %%
docs.head(2)
# Out:
#    cord_uid                                       sha source_x  \
# 0  ug7v899j  d1aafb70c066a2068b02786f8929fd9c900897fb      PMC
# 1  02tnwd4m  6b0567729c2143a66d737eb0a2f63f2dce2e5a7d      PMC
#
#                                                title                    doi  \
# 0  Clinical features of culture-proven Mycoplasma...  10.1186/1471-2334-1-6
# 1  Nitric oxide: a pro-inflammatory mediator in l...           10.1186/rr14
#
#       pmcid pubmed_id license  \
# 0  PMC35282  11472636   no-cc
# 1  PMC59543  11667967   no-cc
#
#                                             abstract publish_time  \
# 0  OBJECTIVE: This retrospective chart review des...   2001-07-04
# 1  Inflammatory diseases of the respiratory tract...   2000-08-15
#
#                                              authors         journal  \
# 0                Madani, Tariq A; Al-Ghamdi, Aisha A  BMC Infect Dis
# 1  Vliet, Albert van der; Eiserich, Jason P; Cros...      Respir Res
#
#                                       pdf_json_files  \
# 0  document_parses/pdf_json/d1aafb70c066a2068b027...
# 1  document_parses/pdf_json/6b0567729c2143a66d737...
#
#                                pmc_json_files  \
# 0  document_parses/pmc_json/PMC35282.xml.json
# 1  document_parses/pmc_json/PMC59543.xml.json
#
#                                                  url  \
# 0  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...
# 1  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
#
#                                                 text
# 0  clinical feature culture prove mycoplasma pneu...
# 1  nitric oxide pro inflammatory mediator lung di...

# %% [markdown]
# # Building Vocabulary and selecting keywords

# %%
documents = docs['text'].tolist() # getting the text column and converting it into a list

# %%
# creating a vocabulary of words, ignoring the word that appear in 85% of documents
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(max_df=0.85)
token_count_vector = vectorizer.fit_transform(documents) 
# creates the vocabulary, the result is a sparse representation of count of each word

# %%
token_count_vector.shape
# The shape is (1000,12295) since we have 1000 documents and vocabulary size is 12295
# Out:
# (1000, 12295)

# %%
token_count_vector.toarray()[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
list(vectorizer.vocabulary_.keys())[:5] # looking at first 5 words of vocabulary
# Out:
# ['clinical', 'feature', 'culture', 'prove', 'mycoplasma']

# %% [markdown]
# # Extracting keywords

# %%
# First compute the IDF(InverseDocumentFrequency) values. For this, we take  the sparse matrix generated from CountVectorizer 
# (token_count_vector) to calculate the IDF by invoking tfidf_transformer.fit(...)

tfidf_transformer=TfidfTransformer(smooth_idf=True,use_idf=True)
    tfidf_transformer.fit(word_count_vector)

# %%
feature_names=vectorizer.get_feature_names() # get all the words from vocabulary

doc = docs['text'] # This is the column for which we want to generate tf-idf
results = [] # list to store the extracted keywords for each document
for d in doc:
     #Transform a count matrix to a normalized tf or tf-idf representation
    tf_idf_vector = tfidf_transformer.transform(vectorizer.transform([d]))
   
  
    #sorting the tf-idf vectors by descending order of scores by calling the function "sort_tf_idf_vector()"
    sorted_items=sort_tf_idf_vector(tf_idf_vector.tocoo())
       
    #extract only the top n; n here is top 20% words with high tf-idf values by calling the function "extract_topn_from_vector()"
    keywords=extract_topn_from_vector(feature_names,sorted_items,int(len(sorted_items)*0.2))
    print(keywords)
    results.append(' '.join(keywords))
# Out:
# ['pneumoniae', 'patients', 'comorbidities', 'pneumonia', 'common', 'infections', 'die', 'king', 'jeddah', 'crepitations', 'abdulaziz', 'saudi', 'mycoplasma', 'chart', 'culture', 'immunocompromised', 'university', 'infants']
# ['inflammatory', 'oxidant', 'presume', 'nitric', 'oxide', 'contribution', 'lung', 'anti', 'evidence', 'tract', 'phagocyte', 'peroxynitrite', 'oxidations', 'comprehensively']
# ['surfactant', 'deficient', 'glycoconjugates', 'organic', 'lipids', 'microorganisms', 'surface', 'contribute', 'abnormal', 'lung', 'express', 'macrophages', 'epithelial', 'variety', 'antigens', 'phosphatidylinositol', 'oligomerized', 'mixtures', 'genitourinary', 'exocrine']
# ['lung', 'diseases', 'role', 'inflammatory', 'tone', 'endothelin']
# ['pneumovirus', 'epithelial', 'gene', 'infectionrespiratory', 'pvm', 'chemoattractant', 'incompletely', 'responses', 'subfamily', 'paramyxoviridae', 'unravel', 'rsv', 'rodents']
# ['trs', 'discontinuous', 'strand', 'subgenomic', 'leader', 'body', 'rna', 'transfer', 'synthesis', 'sequence', 'trss', 'minus', 'template', 'end', 'derive']
# ['transfuse', 'haemoglobin', 'improve', 'ill', 'critically', 'normal', 'level', 'blood', 'rbcs', 'outcomerecent', 'care', 'rct']
# ['symposium', 'medicine', 'intensive', 'care', 'emergency', 'international', 'tutorials', 'seminars', 'enthusiasm', 'con']
# ['heme', 'oxygenase', 'monoxide', 'pulmonary', 'carbon', 'inflammatory', 'anti', 'stress', 'virtue', 'medicineheme', 'ferrous', 'cytoprotection', 'cigarette', 'bilirubin', 'isozyme', 'upregulation', 'smoke', 'rejection', 'nitrogen']
# ['rods', 'data', 'surveillance', 'health', 'send', 'real', 'algorithms', 'public', 'time', 'apply', 'syndrome', 'systemthis', 'sales', 'olympics', 'lease', 'complaint', 'chief', 'warehouse', 'utah']
# ['antizyme', 'frameshift', 'yeast', 'pombe', 'nematodes', 'polyamine', 'feedback', 'frameshifting', 'event', 'translational', 'require']
# ['hnrnp', 'rna', 'mhv', 'mutant', 'synthesis', 'ribonucleoprotein', 'nuclear', 'cytoplasm', 'cytoplasmic', 'replication', 'cellular', 'viral', 'mrna', 'inhibition']
# ['uba', 'domain', 'interact', 'proteins', 'eleven', 'proteinsthe', 'polyubiquitin', 'play', 'reticulocyte', 'lysate']
# ['microtubule', 'vaccinia', 'centrosome', 'microtubules', 'cytoskeleton', 'fashion', 'virus', 'intracellular', 'infection', 'proteins', 'map', 'reorganize', 'iev', 'functionwe']
# ['multi', 'infections', 'array', 'retrovirology', 'viral', 'viruses', 'pcr', 'detect', 'microarray', 'diagnostic', 'virus', 'profilesthere', 'drawbacks', 'dna', 'human', 'readouts', 'faceted', 'many', 'reactivation', 'fight', 'hundreds', 'chip', 'versatile']
# ['ill', 'critically', 'hsv', 'pathogenicity', 'pli', 'lungs', 'normal', 'permeability', 'min', 'simplex', 'herpes', 'patients', 'isolation']
# ['vaccination', 'ring', 'contact', 'smallpox', 'trace', 'sufficient', 'case', 'infectiousness', 'logistics', 'network', 'awareness', 'surveillance', 'assume', 'quickly', 'stochastic', 'mass', 'capacity', 'per', 'vaccinators']
# ['hmyh', 'repair', 'toxic', 'cells', 'dna', 'expression', 'endogenous', 'oxygen', 'hnth', 'lesion', 'excision', 'analysis', 'toxicity', 'oxidative', 'condition', 'blot', 'perform', 'enzymes', 'cell']
# ['alkb', 'domains', 'methylating', 'ptgs', 'plant', 'homologues', 'like', 'rna', 'protect', 'eukaryotes', 'domain', 'viral', 'repair', 'strand', 'genomes', 'map', 'unmethylated', 'phylogenomic', 'pesticides', 'oxoglutarate', 'methylcytosine', 'methylated', 'methyladenine']
# ['legislation', 'laws', 'power', 'emergency', 'patchwork', 'impediment', 'commonwealth', 'emerge', 'saw', 'jurisdictional']
# ['lactis', 'heterologous', 'protein', 'yield', 'production', 'secretion', 'lab', 'proteolysis', 'grade', 'bacterium', 'optimization', 'proteins', 'produce', 'food', 'conformation', 'cytoplasmic', 'size', 'discuss']
# ['signature', 'hts', 'species', 'transfer', 'signatures', 'dna', 'genomic', 'genome', 'horizontal', 'recipient', 'detect', 'look', 'local', 'short', 'propose', 'slide', 'signaturehorizontal', 'prokaryote', 'prokaryotes', 'influenzae']
# ['probe', 'hybridization', 'single', 'deletions', 'complementary', 'insertions', 'oligonucleotide', 'base', 'atm', 'specificity', 'substitutions', 'nucleotide', 'properties', 'mutational', 'microarray', 'resequencing', 'insertion', 'microarrays']
# ['lse', 'testis', 'acetylesterase', 'adult', 'sialic', 'human', 'encode', 'amino', 'specific', 'testisusing', 'spermatogonia', 'spermatogenic', 'spermatocytes', 'developmentally', 'compartmentalization']
# ['pancreatitis', 'mast', 'pain', 'chronic', 'mcdm', 'painful', 'cells', 'vff', 'painless', 'abdomen', 'pancreatic', 'compare', 'pathogenesis', 'humans', 'mice', 'sensitive']
# ['recombination', 'host', 'rate', 'genomes', 'frequency', 'virus', 'frequent', 'single', 'viral', 'multi', 'cycle', 'viruses', 'infectionviral', 'everyday', 'cauliflower', 'replication', 'genome', 'cellular']
# ['pseudoknots', 'torsional', 'mrna', 'frameshifting', 'restraint', 'jacobs', 'dinman', 'prf', 'ribosome', 'ribosomal', 'position', 'model', 'twist']
# ['consensus', 'errors', 'shuffle', 'synthetic', 'population', 'mismatch', 'dna', 'fluorescent', 'fragment', 'iterations', 'gfpuv', 'clone', 'correct']
# ['rna', 'quality', 'metrics', 'integrity', 'rin', 'microcapillary', 'expression', 'classifiers', 'assessment', 'electrophoresis', 'user', 'highly', 'standard', 'gene', 'independent', 'differences', 'traceswhile', 'repositories', 'optional']
# ['frameshift', 'cfmv', 'prf', 'minimal', 'reporter', 'cocksfoot', 'yeast', 'mottle', 'translation', 'replicase', 'termination', 'site', 'dual', 'signal', 'downstream']
# ['fund', 'health', 'public', 'program', 'policy', 'australian', 'continue', 'national', 'future', 'voice', 'unsystematically', 'tga', 'overseas', 'inconsistencies', 'election', 'competencies', 'budget', 'abelson']
# ['module', 'geographic', 'gideon', 'comprehensive', 'web', 'base', 'resource', 'medicine', 'medicinegideon', 'write', 'disease', 'design', 'informatics', 'syndromic', 'interactive', 'graph']
# ['globalization', 'health', 'social', 'access', 'journal', 'matter', 'effect', 'economic', 'subject', 'open', 'wellbeing', 'victory', 'successes', 'strive', 'predilection', 'pertain', 'liberalization', 'interconnectedness', 'hurt', 'healththis', 'geography', 'exemplify', 'debut', 'cheer', 'benchmarks']
# ['recombination', 'rna', 'homomolecular', 'system', 'universal', 'homologous', 'comparison', 'viruses', 'new', 'virus', 'structural', 'recombinationat', 'heteromolecular', 'obtain', 'till', 'brome', 'bmv']
# ['reovirus', 'protease', 'serine', 'uncoating', 'proteases', 'replication', 'independent', 'promonocyte', 'pma', 'inhibitor', 'presence', 'elastase', 'ala', 'acid', 'proteolysis', 'cells', 'cysteine', 'enteric', 'neutrophil', 'vesicular', 'neutrophils', 'replicate', 'ards', 'capacity', 'infection', 'facilitate', 'treat', 'agents', 'subviron']
# ['lna', 'methyl', 'rna', 'duplex', 'nucleotides', 'stabilities', 'lnas', 'separate', 'lock', 'terminal', 'nucleotide', 'least', 'thermodynamic']
# ['draft', 'quality', 'signature', 'sequence', 'nns', 'sap', 'prediction', 'genomes', 'dna', 'target', 'finish', 'error', 'high', 'signatures', 'coverage', 'simulations']
# ['epitopes', 'ontology', 'immune', 'relate', 'information', 'iedb', 'intrinsic', 'concepts', 'capture', 'description', 'database', 'epitope', 'class', 'antigens', 'pathogens', 'semantics', 'reactivitiesbackground', 'emerge']
# ['genes', 'atlantic', 'actin', 'salmon', 'gapdh', 'reference', 'fish', 'rrna', 'smoltification', 'pcr', 'qrt', 'calculations', 'rank', 'six', 'adult', 'evaluation', 'encode', 'real', 'individuals']
# ['copd', 'hmpv', 'smokers', 'patients', 'exacerbations', 'metapneumovirus', 'stable', 'sputum', 'nasal', 'lavage', 'without']
# ['globalization', 'project']
# ['cancer', 'attributable', 'fraction', 'japanese', 'awareness', 'factor', 'risk', 'lifestyle', 'population', 'general', 'men', 'consider', 'cause', 'tend', 'women', 'candidates', 'subject', 'among']
# ['lamp', 'templates', 'precipitation', 'nucleic', 'pei', 'visual', 'device', 'probe', 'poct', 'emit', 'precipitate', 'oligo', 'color', 'detection', 'minute', 'amount', 'cationic', 'amplicon']
# ['drug', 'china', 'abuse', 'hiv', 'aid', 'policies', 'illicit', 'idu', 'needle', 'harm', 'departments', 'government', 'injection', 'past', 'problems', 'users', 'reduction', 'prevention', 'local', 'central', 'program', 'voluntary', 'unpublished', 'triangle', 'smuggle']
# ['wnv', 'humanize', 'monoclonal', 'neutralize', 'nile', 'antibodies', 'antibody', 'therapeutic', 'supplementary', 'west', 'mice', 'iii', 'version', 'domain', 'dose', 'surface']
# ['health', 'local', 'workers', 'duty', 'public', 'willingness', 'pandemic', 'departments', 'perceptions', 'response', 'perception', 'toward', 'multivariate', 'report', 'event', 'influenza', 'threat']
# ['hcps', 'care', 'duty', 'professional', 'obligations', 'sars', 'responsibilities', 'ethics', 'right', 'ought', 'health', 'aftermath', 'cod', 'press', 'issue', 'communicable', 'severely', 'risk', 'pandemic', 'expose', 'expect', 'outbreaks', 'paper', 'outbreak', 'systems', 'provide']
# ['egcg', 'ecg', 'egc', 'cancer', 'line', 'suppress', 'tea', 'gallate', 'catechin', 'ovarian', 'growth', 'cell', 'untreated', 'cells', 'prostate', 'gender']
# ['exacerbation', 'markers', 'severity', 'copd', 'exacerbations', 'level', 'variables', 'iii', 'patient', 'dioxide', 'obstructive', 'study', 'arterial', 'carbon', 'breathe', 'namely', 'meta', 'weak', 'july', 'event', 'change', 'criteria', 'manner', 'consistent', 'chronic', 'pulmonary']
# ['ssh', 'microarray', 'assay', 'cdna', 'hepatoma', 'differentially', 'subtract', 'genes', 'expression', 'transcriptomes', 'low', 'amplicons', 'regular', 'profile', 'tedious', 'combination', 'modify', 'inefficient', 'high', 'original', 'transcripts', 'pair', 'express', 'clone', 'approach', 'directly', 'genomic']
# ['immunomic', 'immunomics', 'functional', 'technology', 'genomics', 'microarray', 'scientific', 'challenge', 'responses', 'vision', 'rewardsthe', 'immunonic', 'envision', 'coherent', 'allergies', 'addressable', 'computation', 'big', 'speculate']
# ['outbreaks', 'smallpox', 'median', 'generations', 'case', 'america', 'north', 'europe', 'index', 'diagnose', 'generation', 'war', 'initial', 'review', 'publications', 'correctly', 'library', 'pattern', 'hospitalize']
# ['definitions', 'case', 'shd', 'lhd', 'precision', 'reliability', 'examples', 'surveillance', 'robin', 'revision', 'check', 'departments', 'round', 'health', 'format', 'list', 'report', 'predictive', 'criteria', 'sensitivity', 'value']
# ['vap', 'units', 'intensive', 'pneumonia', 'hospital', 'oropharynx', 'controlventilator', 'care', 'mortality', 'money', 'colonize', 'save']
# ['enterovirus', 'sarawak', 'outbreaks', 'human', 'malaysia', 'sentinel', 'throat', 'mouth', 'foot', 'swab', 'hand', 'circulate', 'outbreak', 'surveillance', 'region', 'yearsbackground', 'vesicle', 'cyclical', 'isolate']
# ['vsv', 'growth', 'attenuation', 'vaccines', 'attenuate', 'virus', 'model', 'link', 'engineer', 'position', 'alter', 'live', 'wild', 'establish', 'viruseslive', 'nonsegmented', 'generalization', 'rearrangements', 'manipulations', 'genome', 'mechanisms', 'overexpressing', 'hijack', 'change']
# ['sirnas', 'rnai', 'delivery', 'pei', 'sirna', 'interference', 'intact', 'organs', 'tumor', 'systemic', 'target', 'application', 'promise', 'systems', 'vivo']
# ['oocyte', 'genes', 'maturation', 'ovulation', 'regulation', 'vitellogenesis', 'preovulatory', 'exhibit', 'ovarian', 'cluster', 'differentially', 'time', 'analysis', 'trout', 'slc', 'rainbow', 'aqp', 'adam', 'expression', 'ovary', 'fish', 'dramatic', 'cxcl', 'post', 'ace', 'pattern', 'use']
# ['epiflex', 'locations', 'model', 'disease', 'epidemics', 'object', 'contact', 'phenomena', 'characteristic', 'computer', 'within', 'diseases', 'system', 'variety', 'field', 'phase', 'better', 'individuals', 'epidemic', 'define', 'worthwhile', 'superspreading', 'multimodality', 'inhabit', 'epiflexbackground', 'compression', 'data', 'spread', 'result']
# ['test', 'genetic', 'newborn', 'incorrect', 'cftr', 'newborns', 'sample', 'decode', 'liquid', 'screen', 'target', 'genotyped', 'correctly', 'platform', 'call', 'step', 'state', 'plx', 'multiplexing', 'multicode']
# ['frameshifting', 'antisense', 'orf', 'shift', 'site', 'ribosomal', 'frame', 'read', 'induce', 'downstream', 'translation', 'locate', 'frameshiftingprogrammed', 'divert', 'mechanism', 'uga']
# ['recode', 'frameshifting', 'solfataricus', 'fucosidase', 'fuca', 'archaea', 'split', 'gene', 'translational', 'full', 'expression', 'events', 'program', 'length']
# ['helicases', 'rna', 'encode', 'orfs', 'viruses', 'strand', 'genomes', 'hiv', 'ability', 'surmise', 'replicationviruses', 'obligatorily', 'devoid', 'replicative']
# ['mimox', 'epitope', 'phage', 'mimotopes', 'map', 'tool', 'display', 'section', 'web', 'base', 'exist', 'convenient', 'embed', 'consensus', 'research', 'native', 'service', 'view', 'online', 'access', 'evaluate', 'utilize', 'community']
# ['fgf', 'remyelination', 'demyelination', 'chronic', 'mice', 'oligodendrocyte', 'cuprizone', 'demyelinate', 'endogenous', 'chronically', 'regeneration', 'progenitor', 'removal', 'typically', 'exhibit', 'wild', 'remyelinated', 'remyelinate', 'oligodendroglial', 'nonlesioned']
# ['resequencing', 'entries', 'detail', 'sequence', 'automate', 'pathogens', 'information', 'databases', 'algorithm', 'assay', 'call', 'microarray', 'identification', 'analysis', 'pathogen', 'unassisted', 'microarraysthere']
# ['anticodon', 'formula', 'position', 'text', 'mcm', 'loop', 'see', 'wild', 'trna', 'simulations', 'simulation', 'stem', 'type', 'modify', 'mrna', 'dynamics']
# ['probe', 'oligonucleotide', 'quencher', 'endo', 'linker', 'rigid', 'helper', 'endonuclease', 'end', 'fluorescent', 'substrate', 'efficiently', 'strand']
# ['ethical', 'framework', 'plan', 'pandemic', 'decision', 'hospitals', 'reflection', 'ethics', 'influenza', 'guide', 'make', 'health', 'help', 'paper', 'outbreak', 'hospital', 'vet', 'tell', 'stakeholder']
# ['patients', 'olb', 'ards', 'biopsy', 'pathological', 'stage', 'alteration', 'diagnose', 'rate', 'early', 'treatment', 'immunocompromised', 'complication', 'mortality', 'oxygen', 'retrospective', 'diagnostic', 'survival', 'distress', 'open', 'hospital', 'mean']
# ['host', 'pathogens', 'associations', 'multi', 'analyse', 'viruses', 'indices', 'pattern', 'selective', 'plant', 'test', 'distribution', 'evolution', 'specialisation']
# ['trace', 'effectiveness', 'contact', 'effective', 'proportion', 'mouth', 'foot', 'smallpox', 'emerge', 'variability', 'sars', 'delay', 'yet', 'general', 'time', 'consider', 'iterative', 'brink']
# ['delay', 'country', 'travel', 'source', 'travelers', 'region', 'epidemic', 'pandemic', 'chance', 'risk', 'flight', 'border', 'pharmaceutical', 'time', 'interventions', 'infect', 'prevent', 'screen', 'influenza', 'momentum', 'minimally', 'exit', 'spread']
# ['antibody', 'ebola', 'neutralize', 'macaques', 'challenge', 'monoclonal', 'rhesus', 'protect', 'virus', 'infection', 'fail', 'dose', 'monkeysprophylaxis']
# ['organizational', 'public', 'alberta', 'health', 'inter', 'preparedness', 'network', 'systems', 'institutional', 'design', 'agency', 'tie', 'fund', 'threats', 'canada', 'level', 'prepare', 'environmental', 'components', 'study']
# ['dysfunction', 'cognitive', 'mechanisms', 'illness', 'critical', 'resolution', 'brain', 'markers', 'associate', 'influence', 'transmitter', 'therapeuticscognitive', 'anticholinergic', 'pathophysiologic', 'neuro']
# ['procat', 'microarrays', 'protein', 'approach', 'microarraysprotein', 'artifacts', 'signal', 'many']
# ['computational', 'positional', 'gaba', 'cluster', 'mammalian', 'improve', 'site', 'subunit', 'regulatory', 'bind', 'robustness', 'predictions', 'predict', 'receptor', 'accuracy', 'gene', 'experimental', 'tfbs', 'pharmacologically', 'neurotransmitter', 'imperfectly', 'genesunderstanding']
# ['farm', 'reproductive', 'number', 'hpai', 'commercial', 'outbreaks', 'poultry', 'eradicate', 'avian', 'transmissibility', 'close', 'pathogenic', 'outbreak', 'control', 'estimate', 'therefore', 'influenza']
# ['plan', 'pandemic', 'influsim', 'influenza', 'tool', 'software', 'operate', 'public', 'design', 'preparedness', 'optimal', 'health', 'model', 'apply', 'produce', 'operability', 'influsimbackground', 'generality', 'computers', 'administrations', 'sickness', 'realism']
# ['honey', 'defences', 'bee', 'apis', 'insect', 'immunity', 'social', 'pathways', 'individual', 'pathogens', 'orthologues', 'melliferasocial', 'coevolved']
# ['elad', 'ubiquitin', 'ulp', 'senp', 'clan', 'deubiquitinating', 'coli', 'protease', 'ubls', 'hydrolases', 'homologs', 'eukaryotes', 'proteases', 'eukaryotic', 'specific', 'strain', 'pathogenic', 'ubl', 'sulfatase', 'ssel']
# ['ceacam', 'bind', 'ile', 'ceacams', 'residues', 'bacterial', 'pathogens', 'gln', 'domain', 'human', 'receptor', 'model', 'mutations', 'target', 'molecules', 'distinct', 'structural', 'site', 'tyr', 'rei', 'meningitidis', 'intraspecies', 'igv']
# ['iris', 'syndrome', 'infectious', 'manifestations', 'treatment', 'reconstitution', 'opportunistic', 'art', 'burden', 'initiate', 'immune', 'underlie', 'therapy', 'inflammatory', 'optionsthe', 'exuberant', 'condition', 'common']
# ['influenza', 'species', 'viral', 'surveillance', 'genotypes', 'esi', 'pcr', 'analysis', 'infer', 'mix', 'subtypes', 'mass', 'emergence', 'circulate', 'global', 'avian', 'rapid', 'identification', 'evolution', 'spectrometrybackground', 'base', 'identify', 'isolate']
# ['transmission', 'parameters', 'fmd', 'farm', 'mouth', 'foot', 'epidemic', 'great', 'estimate', 'proactively', 'mcmc', 'cull', 'britaindespite', 'britain']
# ['pvm', 'macrophage', 'mip', 'mouse', 'rodent', 'line', 'virus', 'cell', 'raw', 'proinflammatory', 'titers', 'replication', 'synthesis', 'pneumonia', 'inflammatory', 'pneumovirinae', 'linepneumonia']
# ['exercise', 'tabletop', 'departments', 'health', 'preparedness', 'participate', 'conduct', 'public', 'design', 'emergency', 'emergencies', 'evaluation', 'local', 'strengths', 'lessons', 'state', 'develop', 'learn', 'assess', 'performance', 'efforts', 'action', 'threatsbackground', 'partnership', 'manmade', 'logistically']
# ['affymetrix', 'annotation', 'transcript', 'probesets', 'probeset', 'level', 'gene', 'expression', 'array', 'refine', 'interpretation', 'microarray', 'standard', 'link', 'protein', 'databackground']
# ['trx', 'redox', 'extracellular', 'thioredoxin', 'disulfide', 'receptor', 'signal', 'ligand', 'cytokine', 'surface', 'interactions', 'oxidoreductase', 'catalytically', 'catalyst', 'identify', 'mechanism']
# ['isg', 'ubiquitin', 'usp', 'dub', 'ubls', 'proteases', 'isot', 'proteasome', 'conjugate', 'protease', 'utilize', 'family', 'might', 'therefore', 'ubp', 'promiscuous', 'newcomer', 'isopeptidase', 'innocuous', 'deubiquitinasesbackground', 'deconjugating']
# ['melt', 'mutation', 'mutations', 'scan', 'sample', 'mismatch', 'screen', 'enzymatic', 'genetic', 'dna', 'pcr', 'contain', 'technology', 'biology', 'enable', 'position', 'cancer', 'real', 'rapid', 'surveyor']
# ['coil', 'helical', 'parasite', 'malaria', 'vaccine', 'peptides', 'antibodies', 'native', 'sera', 'candidates', 'peptide', 'active', 'select', 'rapid', 'identification', 'motifto', 'erythrocytic']
# ['flugenome', 'reassortment', 'lineages', 'genotypes', 'nomenclature', 'web', 'influenza', 'segment', 'genotype', 'viruses', 'evolution', 'tool', 'virusinfluenza', 'modalities', 'interrogate']
# ['pharmaceutical', 'stockpile', 'pandemic', 'antiviral', 'influsim', 'height', 'reduction', 'plan', 'interventions', 'contact', 'drug', 'wave', 'measure', 'intervention', 'peak', 'non', 'much', 'even', 'epidemic', 'influenza', 'protraction', 'overtax', 'win']
# ['vaccines', 'dna', 'protozoan', 'parasites', 'advance', 'new', 'leishmaniasis', 'curiosity', 'challengesover', 'chagas', 'challenge']
# ['household', 'reproduction', 'number', 'estimate', 'track', 'households', 'simulations', 'infect', 'outbreak', 'individual', 'time', 'define', 'estimator', 'epidemicreproduction', 'emerge', 'transmission', 'play', 'method']
# ['responses', 'cell', 'cells', 'antiviral', 'cytomegalovirus', 'mcmv', 'early', 'promote', 'accelerate', 'ability', 'killer', 'control', 'dendritic', 'cytokine', 'help', 'ifn', 'innate', 'natural', 'activation', 'contribute', 'cytomegalovirusunderstanding', 'congenic', 'cdcs', 'viral', 'production']
# ['fair', 'poultry', 'powder', 'county', 'contamination', 'box', 'pathogen', 'light', 'participants', 'exhibit', 'venue', 'surreptitiously']
# ['apobec', 'perv', 'endogenous', 'pig', 'retrovirus', 'human', 'transmission', 'restriction', 'anti', 'exogenous', 'zoonotic', 'innate', 'inhibition', 'xenotransplantation', 'thwart', 'hypermutations', 'gthe', 'fortify', 'dominantly']
# ['hpai', 'tuva', 'russia', 'pathogenic', 'duck', 'sera', 'virus', 'vaccines', 'model', 'sensivity', 'quinghai', 'mld', 'ivpi', 'characterize', 'hypercytokinemia', 'huge', 'epizooty', 'adamantanes', 'occur']
# ['rna', 'pseudoknots', 'structure', 'fold', 'prediction', 'heuristic', 'map', 'pseudoknot', 'approach', 'foldingpredicting', 'thermodynamics', 'historically', 'many', 'neglect', 'flexibility']
# ['conjugate', 'arginine', 'correction', 'toxicity', 'oligoarginine', 'splice', 'uptake', 'activity', 'concentration', 'cpp', 'residues', 'cellular', 'pmo']
# ['save', 'genomics', 'world', 'view', 'scourge', 'milstein', 'intricacies', 'grand', 'award', 'functional', 'advent', 'cellular', 'want', 'excite', 'change', 'lose']
# ['electrospray', 'tnt', 'ionisation', 'cleavable', 'conjugate', 'esi', 'pna', 'probe', 'nucleic', 'tandem', 'peptide', 'hybridization', 'mass', 'acid', 'synthesis']
# ['hax', 'utr', 'pol', 'hairpin', 'element', 'transcriptional', 'regulatory', 'bind', 'post', 'expression', 'polymerase', 'regulation', 'mrna', 'protein', 'polyadenylation', 'dna', 'carcinogenesis', 'form']
# ['gpg', 'global', 'health', 'concept', 'initiatives', 'gpgs', 'promote', 'goals', 'development', 'pose', 'policy', 'traditional', 'conclude', 'general', 'paper', 'apply', 'define', 'consider', 'rhetoric', 'potentialthe', 'overstretch', 'mobilisation', 'mdg']
# ['sequelae', 'survivors', 'paediatric', 'psychological', 'physical', 'intensive', 'care', 'quality', 'life', 'original', 'parent', 'study', 'report', 'seem', 'determine', 'treatment']
# ['cgs', 'sequence', 'genome', 'insertions', 'snps', 'element', 'detect', 'mutations', 'bacterium', 'deletion', 'comparative', 'one', 'accuracy', 'present', 'resequenced', 'resequence', 'nimblegen', 'lambda', 'kohara']
# ['hiv', 'vaccines', 'groupthe', 'enterprise', 'directions']
# ['dengue', 'proteasome', 'host', 'fever', 'tac', 'replication', 'upregulated', 'genes', 'pathway', 'line', 'ubiquitin', 'gene', 'expression', 'response', 'viral', 'microarray', 'infection', 'throughput', 'ifn', 'quantitative', 'cell', 'blood', 'viperin', 'seriousness', 'alln', 'overexpressed']
# ['ceacam', 'cea', 'family', 'gene', 'immune', 'ceacams', 'dog', 'evolution', 'carcinoembryonic', 'receptors', 'canine', 'proteins', 'pathogens', 'species', 'purify', 'cod', 'bear', 'relate', 'selection', 'mrna', 'domain', 'complete', 'antigen', 'activation', 'specific', 'regulate', 'tremendous']
# ['nucleolus', 'nucleolar', 'nucleus', 'ribosomal', 'nucleoplasm', 'nuclear', 'ribosome', 'synthesize', 'rnas', 'activity', 'cycle', 'proteins', 'polymerase', 'domain', 'cell', 'regulate']
# ['banaba', 'glucose', 'pgg', 'activity', 'extract', 'uptake', 'scientists', 'lagerstroemin', 'lagerstroemia', 'corosolic', 'adipocytes', 'insulin', 'chen', 'responsible', 'water', 'anti', 'transport', 'identify', 'compound', 'components', 'exhibit', 'different', 'model']
# ['ship', 'serial', 'communities', 'reproductive', 'interval', 'maryland', 'influenza', 'number', 'populations', 'epidemic', 'days', 'statements', 'pandemicbackground', 'nonparametric', 'enclose', 'method']
# ['surfactant', 'trials', 'days', 'failure', 'children', 'interval', 'confidence', 'mechanically', 'ventilate', 'acute', 'ventilator', 'respiratory', 'randomize', 'exogenous', 'difference', 'mortality', 'enrol', 'reduce']
# ['cross', 'avian', 'transmission', 'range', 'human', 'influenza', 'humansinfluenza', 'humans', 'species', 'waterfowl', 'fulminant']
# ['triage', 'critical', 'care', 'plan', 'recognise', 'justice', 'distributive', 'contingency', 'cohorting', 'casualty', 'careworst', 'candid', 'facility', 'faceted', 'transparent', 'planners']
# ['health', 'outbreak', 'avian', 'turkey', 'van', 'influenza', 'service', 'dogubeyazit', 'integrate', 'experience', 'animal', 'coordination', 'personnel', 'coordinate', 'surveillance', 'preparation', 'region', 'epidemic', 'first', 'interview', 'control', 'care', 'public', 'play', 'months', 'human', 'national', 'plan', 'management', 'case', 'role', 'lack']
# ['sentinel', 'influenza', 'europe', 'activity', 'season', 'weeks', 'spread', 'peak', 'report', 'clinical', 'match', 'across', 'east', 'west', 'south', 'north', 'winter', 'eiss', 'eight', 'gps']
# ['sepsis', 'difficulties', 'campaign', 'procedures', 'survive', 'sepsisthe', 'proposals', 'promptly', 'pragmatism', 'formalize']
# ['sepsis', 'vector', 'luc', 'vectors', 'luciferase', 'clp', 'gene', 'ards', 'alveolar', 'immunostaining', 'harvest', 'induce', 'transduction', 'simian', 'immunoassay', 'rat', 'vivo', 'detection', 'light', 'double', 'evaluate', 'expression', 'pulmonary']
# ['transfectants', 'glycosylation', 'dcat', 'receptor', 'virus', 'moloney', 'mcat', 'dunni', 'cytopathicity', 'ecotropic', 'syncytium', 'mouse', 'variant', 'spl', 'nih', 'friend', 'entry', 'mlv', 'env']
# ['frameshift', 'tar', 'initiation', 'translation', 'hiv', 'efficiency', 'alter', 'rate', 'stimulatory', 'mrna', 'ribosomes', 'pkr', 'luciferase', 'change', 'rna', 'structure']
# ['sss', 'taiwan', 'surveillance', 'syndromic', 'system', 'march', 'illnesses', 'emergency', 'nationwide', 'team', 'spike', 'real', 'disease', 'systems', 'physicians', 'syndrome', 'establish', 'department', 'public', 'like', 'hospitals', 'infectious', 'international', 'start', 'health', 'outbreak', 'better', 'control', 'two']
# ['reactivity', 'ctl', 'cross', 'tcr', 'cell', 'similarity', 'amino', 'biochemically', 'acid', 'identity', 'model', 'extent', 'epitopes', 'peptides', 'diverse', 'recognition', 'peptide', 'field', 'recognize', 'able']
# ['hrv', 'rhinovirus', 'qpm', 'divergent', 'strain', 'detect', 'members', 'hrvs', 'polyprotein', 'silico', 'deletions', 'clinical', 'species', 'distinguish', 'genus', 'call', 'six', 'frequently', 'yet', 'feature', 'hospital', 'individuals', 'analyse', 'shortest', 'footprints', 'artis', 'antigenicity', 'previously']
# ['ali', 'pmn', 'apoptosis', 'lung', 'epithelial', 'injury', 'hypotheses', 'neutrophil', 'recruitment', 'cell', 'interfere', 'therapeutic', 'rnasin', 'pathomechanisms', 'morbid', 'small', 'mind', 'fas']
# ['rna', 'selection', 'crossover', 'recombinants', 'recombination', 'rnas', 'acceptor', 'affect', 'recombinant', 'site', 'rate', 'repeat', 'drive']
# ['epigrass', 'network', 'model', 'simulation', 'construction', 'task', 'complex', 'simulate', 'software', 'epidemiological', 'facilitate', 'epidemic', 'tool', 'workflow', 'parameterization', 'networksbackground', 'daunt']
# ['lacv', 'monkey', 'rhesus', 'cns', 'crosse', 'mice', 'olfactory', 'replicate', 'pfu', 'intranasally', 'via', 'titer', 'infect', 'neurons', 'nasal', 'immunogenicity', 'inoculation', 'infectivity', 'encephalitis', 'neutralize', 'animal', 'strong']
# ['tail', 'terminal', 'disorder', 'intrinsically', 'domain', 'phosphoprotein', 'structure', 'fold', 'nucleoprotein', 'resonance', 'complex', 'consist', 'induce', 'sit', 'virus', 'region', 'unfoldedmeasles', 'themononegavirales', 'themeasles', 'heteronuclear']
# ['vehicles', 'behaviors', 'raw', 'know', 'modes', 'attitudes', 'practice', 'poultry', 'hygienic', 'information', 'transmission', 'touch', 'meat', 'socioeconomic', 'compliance', 'animals', 'knowledge', 'food', 'handle', 'perceive', 'avoid']
# ['viruses', 'season', 'evolution', 'influenza', 'period', 'complete', 'strain', 'observe', 'glycosylations', 'denmark', 'genome', 'circulate', 'study', 'characterise', 'knowledge', 'site', 'influence', 'lineages', 'prevalent', 'genetic', 'europe', 'human', 'genomes', 'especially']
# ['duty', 'profession', 'consent', 'presume', 'participants', 'risk', 'argument', 'choose', 'hcws', 'inform', 'care', 'medical', 'say', 'dentists', 'justify', 'moral', 'provide', 'occupational', 'would', 'treat', 'diseases', 'whether', 'education', 'physicians', 'train', 'problem', 'aid', 'certain', 'level', 'protective']
# ['feed', 'shake', 'methanol', 'flasks', 'batch', 'pastoris', 'aox', 'collagen', 'solution', 'wireless', 'production', 'control', 'apply', 'optimization', 'starvation', 'pichia', 'fermentation', 'monitor', 'pulse', 'human', 'promoter', 'continuous', 'example', 'addition', 'cost']
# ['hmgb', 'activate', 'endogenous', 'alarmin', 'function', 'immune', 'inflammatory', 'infectious', 'release', 'injury', 'molecules', 'pathogens', 'signalingwhile', 'restorative', 'milieu', 'constituents', 'archetypical', 'alarmins', 'recent', 'condition']
# ['translation', 'orf', 'protein', 'ires', 'term', 'vitro', 'initiation', 'rna', 'system', 'norovirus', 'enteric', 'bovine', 'capsid', 'like', 'process', 'detect', 'follow', 'epitope', 'synthesis', 'genomic', 'sequence', 'encode']
# ['household', 'influenza', 'index', 'households', 'secondary', 'randomize', 'attack', 'ratios', 'visit', 'trial', 'laboratory', 'subject', 'confirm', 'interventions', 'contact', 'hygiene', 'pharmaceutical', 'home', 'mask', 'differ', 'face', 'members', 'hand', 'hours', 'case']
# ['emerge', 'infectious', 'estimation', 'time', 'real', 'diseases', 'number', 'case', 'epidemiological', 'bayesian', 'significance', 'transmissibility', 'change', 'standard', 'statistical', 'worldwide', 'surveillance', 'influenza', 'violations', 'observables', 'bound', 'allocations', 'humans', 'methodology', 'introductions']
# ['detectiv', 'normalization', 'visualization', 'software', 'offer', 'test', 'tool', 'datadna']
# ['fmdv', 'silkworm', 'vaccine', 'subunit', 'fmd', 'baculovirus', 'animals', 'mouth', 'foot', 'bovine', 'traditional', 'expression', 'develop', 'dose', 'hnk', 'economical', 'cha', 'workshop', 'vaccinebackground', 'safer', 'hoof', 'dilute']
# ['mix', 'contact', 'trace', 'network', 'nod', 'epidemic', 'disassortatively', 'disassortative', 'assortatively', 'assortative', 'efficacy', 'dynamics', 'connect', 'pattern', 'epidemics']
# ['plan', 'practice', 'general', 'framework', 'appraise', 'health', 'influenza', 'pandemic', 'guide', 'care', 'available', 'environment', 'domains', 'address', 'five', 'sketchy', 'managerial', 'haddon', 'grey', 'collaborations', 'identify']
# ['stress', 'apoptosis', 'yeast', 'apoptotic', 'degradation', 'pcd', 'fragmentation', 'induce', 'death', 'oxidative', 'rnas', 'ribosomal', 'expose', 'depend', 'cell', 'yeastorganisms', 'yca', 'respire', 'metacaspase', 'hyperosmotic']
# ['host', 'evolve', 'virus', 'metabolism', 'substitution', 'viral', 'transmit', 'new', 'symptoms', 'contribute', 'vpg', 'spill', 'radically', 'passages', 'expressionviruses', 'epistatically', 'allow', 'usual', 'fix', 'ancestral', 'exacerbate']
# ['hmpv', 'rhmpv', 'deletion', 'attenuate', 'metapneumovirus', 'hamsters', 'replication', 'candidate', 'genomic', 'alter', 'polymerase', 'growth', 'live', 'transcription', 'vivo', 'complex', 'hamstersbackground', 'vitro', 'vaccine']
# ['mucosal', 'breakdown', 'tlrs', 'epithelial', 'lead', 'inflammation', 'development', 'innocent', 'controversy', 'bystander', 'epithelium', 'activation', 'inflammatory', 'intestinal', 'toll', 'barrier', 'kidney', 'determine', 'injury', 'central', 'state', 'work']
# ['ubiquitination', 'cvb', 'ubiquitin', 'proteasome', 'viral', 'replication', 'coxsackievirus', 'protein', 'apparent', 'titers', 'modification', 'degradation', 'function', 'polymerase', 'regulation', 'inhibition', 'role', 'translationally', 'coxsackieviral', 'decrease', 'cardiomyocytes', 'mechanisms']
# ['mask', 'wear', 'respirators', 'protection', 'personal', 'home', 'imperfect', 'aerosol', 'exposure', 'general', 'volunteer', 'type', 'surgical', 'make', 'face', 'degree', 'healthy']
# ['oct', 'cancer', 'lung', 'stem', 'renew', 'expression', 'sirna', 'like', 'marker', 'cells', 'self', 'treatment', 'maintain', 'properties', 'spheres', 'ribose', 'prominin', 'parp', 'paclitaxel', 'cisplatin', 'chemoradiotherapy', 'chemoradioresistant']
# ['piglets', 'genes', 'rotavirus', 'regulate', 'villous', 'enterocytes', 'microarray', 'germ', 'tip', 'free', 'infect', 'virulent', 'mucosal', 'supplementary', 'transport', 'material', 'expression', 'cluster', 'ifn', 'regulation', 'protein', 'villus', 'scrap', 'rotavirusgerm', 'jejunum']
# ['staff', 'enteric', 'ccc', 'illness', 'centre', 'child', 'manage', 'cccs', 'health', 'challenge', 'officials', 'public', 'experience', 'guidance', 'outbreaks', 'focus', 'decisions', 'care', 'assist', 'risk', 'action']
# ['divergence', 'subtype', 'substitution', 'time', 'rate', 'clock', 'date', 'ago', 'estimate', 'researchers', 'viral', 'subtypes', 'sequence', 'zeroth', 'triplets']
# ['lps', 'tlr', 'antagonists', 'shock', 'gram', 'septic', 'cause', 'sepsis', 'bacteria', 'release', 'clinical', 'cytokines', 'treat', 'negative', 'death', 'inflammatory', 'malfunction', 'diseasessepsis', 'blockage', 'amphipathic', 'receptor']
# ['dengue', 'mip', 'cytokine', 'ifn', 'severity', 'patients', 'manifestations', 'mild', 'associate', 'mcp', 'csf', 'disease', 'multiplex', 'severe', 'clinical', 'cytokines', 'contrast', 'profile', 'increase']
# ['species', 'discovery', 'curve', 'virus', 'human', 'viruses', 'new', 'viruseson', 'undiscovered', 'extrapolate', 'generate']
# ['selection', 'alignment', 'alignments', 'frame', 'read', 'fix', 'explicitly', 'bias', 'overlap', 'inference', 'run', 'complicate', 'uncertainty', 'estimation', 'accuracy', 'integrate', 'cod', 'mutation', 'genomes', 'statistical', 'one', 'appear']
# ['sequence', 'kong', 'hong', 'seasonality', 'influenza', 'nai', 'syd', 'mos', 'season', 'viruses', 'elsewhere', 'mutations', 'resistance', 'migration', 'location', 'different', 'naturally', 'neuraminidase', 'continue', 'may', 'date', 'relatively', 'circulate']
# ['macrophages', 'lung', 'lungs', 'neutrophils', 'pandemic', 'influenza', 'virus', 'similarities', 'infect', 'viruses', 'infection', 'mice', 'immune', 'pathogenic', 'potentially', 'mouse', 'inflammatory', 'micefatal']
# ['psgs', 'selection', 'genes', 'positive', 'enrich', 'evidence', 'mammalian', 'evolution', 'perception', 'mammals', 'power', 'genome', 'specific', 'scan', 'six', 'additional', 'wide', 'previous', 'testes', 'taste', 'nonselection', 'genomesgenome', 'fdr', 'eutherian', 'enrichments', 'chemosensory']
# ['nanofluidic', 'digital', 'algorithm', 'copy', 'utilize', 'variation', 'number', 'mathematically', 'devicecopy']
# ['wnv', 'climate', 'scenarios', 'simulate', 'larviciding', 'geosimulation', 'crow', 'forecast', 'system', 'nile', 'mosquitoes', 'west', 'simulation', 'measure', 'place', 'vector', 'agent', 'appropriate', 'multi', 'management', 'map', 'populations', 'develop', 'dynamics', 'select', 'interactions', 'model', 'systems', 'visualisation', 'roost', 'quebec']
# ['medicine', 'alternative', 'aid', 'sessions', 'aidsimpact', 'asia', 'session', 'cultural', 'actors', 'retroviral', 'hiv', 'africa', 'meet', 'settings', 'insights', 'resource', 'poor', 'live', 'therapy', 'senegal', 'marseille', 'legitimacy']
# ['reassortant', 'genetic', 'viruses', 'parent', 'interlineage', 'diversity', 'reassortment', 'hpai', 'emergence', 'dynamics', 'influenza', 'reassorted', 'onward', 'indonesiah', 'diversify', 'humans', 'phylogeography', 'parsimony', 'jakarta', 'transmission', 'strain']
# ['endothelial', 'gammaherpesvirus', 'cells', 'viability', 'cyclin', 'lysis', 'infection', 'infect', 'gammaherpesviruses', 'lytic', 'cell', 'viral', 'expression', 'replication', 'continue', 'extend', 'source', 'virus', 'surface', 'provide', 'neoplasms', 'burkitt', 'adherent', 'production', 'primary', 'characterize']
# ['begomoviruses', 'codon', 'usage', 'bipartite', 'old', 'world', 'synonymous', 'ones', 'genes', 'bias', 'worlds', 'usages', 'monopartite']
# ['rfviia', 'dah', 'intrapulmonary', 'administration', 'vii', 'case', 'haemorrhage', 'thrombotic', 'bleed', 'procedure', 'diffuse', 'complications', 'alveolar', 'icu', 'observe', 'activate', 'two', 'recombinant', 'tachypnea']
# ['upr', 'pfts', 'pft', 'mapk', 'toxins', 'defenses', 'unfold', 'response', 'pathway', 'bacterial', 'activation', 'xbp', 'ire', 'arm', 'activate', 'loss', 'protective', 'since']
# ['shrews', 'parasites', 'immune', 'tissue', 'wald', 'haemolymphatic', 'effectively', 'lymphatic', 'respond', 'adults', 'adult', 'breed', 'natural', 'wild', 'animals', 'bring', 'depletion', 'common', 'composition', 'function', 'may', 'plasma', 'sorex', 'shrewbackground', 'mat', 'longevity', 'lifespans', 'immunosenescence']
# ['determinant', 'heteroclitic', 'ctl', 'engineer', 'subdominant', 'basis', 'enhancement', 'substitution', 'cell', 'responses', 'escape', 'stability', 'epitope', 'prevention', 'complex', 'wildtype', 'determinanthigh', 'enhance', 'pmhc', 'histocompatibility']
# ['hcv', 'hiv', 'hepatic', 'liver', 'intra', 'specific', 'cells', 'individuals', 'infect', 'bystander', 'mono', 'biopsies', 'lymphocytes', 'responses']
# ['hfs', 'diagnosis', 'hypofibrinogenemia', 'multiorgan', 'hemophagocytic', 'failure', 'case', 'due', 'therapy', 'syndrome', 'thrombopenia', 'hypertriglyceridemia', 'hyperferritinemia', 'hlh', 'hemophagocytosis', 'bicytopenia', 'sixteen', 'reactants']
# ['copy', 'number', 'digital', 'array', 'nanofluidic', 'sample', 'breast', 'gene', 'variations', 'dna', 'difference', 'use', 'technology', 'capable', 'techniques', 'throughput', 'cancer', 'twofold']
# ['phe', 'hospitals', 'staff', 'train', 'hospital', 'preparedness', 'emergency', 'china', 'survey', 'management', 'stockpile', 'capacities', 'medical', 'could', 'valid', 'four', 'demographic', 'status', 'capacity', 'relate', 'plan', 'community', 'systems', 'laboratory', 'drug']
# ['wasp', 'ichnovirus', 'ascoviruses', 'ascovirus', 'ichnoviruses', 'genomes', 'lateral', 'wasps', 'symbiogenesis', 'ichneumonid', 'virions', 'dna', 'evidence', 'transfer', 'particles', 'proteins', 'passive', 'molecular', 'replicate', 'also', 'evolution', 'symbiogenesisbackground']
# ['immunity', 'exist', 'pre', 'ebola', 'vaccine', 'nab', 'bal', 'pei', 'bypass', 'ifn', 'oral', 'adenovirus', 'nasal', 'compromise', 'mice', 'survive', 'reduce', 'vaccinate', 'cells']
# ['apm', 'respiratory', 'pneumonia', 'screen', 'reportedly', 'mimivirusacanthamoeba']
# ['allocation']
# ['psychological', 'distress', 'zone', 'horse', 'industry', 'high', 'outbreak', 'disease', 'equine', 'population', 'respondents', 'income', 'level', 'australia', 'whose', 'measure', 'study', 'prevalence', 'experience', 'people', 'first', 'source', 'live', 'greater', 'link', 'collect']
# ['socs', 'ifn', 'stat', 'induction', 'signal', 'type', 'viral', 'jak', 'influenza', 'phosphorylation', 'expression', 'viruses', 'dependent', 'deficient', 'impair', 'protein', 'suppress', 'cells', 'action', 'gene', 'interferon', 'response']
# ['ifn', 'ads', 'adenoviral', 'tlr', 'splenic', 'cytosolic', 'mdcs', 'response', 'mice', 'hypersensitivity', 'adenoviruses', 'myeloid', 'irf', 'endosomal', 'induce', 'lps', 'vivo', 'toxic', 'production', 'signal', 'side', 'kinase', 'recognition', 'induction', 'type']
# ['hses', 'admission', 'vasopressor', 'infusion', 'hours', 'upon', 'early', 'patients', 'shock', 'mmol', 'markers', 'resuscitation', 'hypotension', 'encephalopathy', 'platelet', 'edema', 'neurological', 'diagnosis', 'count', 'enzymes', 'fluid']
# ['pair', 'fold', 'rna', 'base', 'pfold', 'thermodynamic', 'predict', 'probability', 'structure', 'currently', 'conserve', 'smoothen', 'rnaalifold', 'petfold', 'incorrectly', 'energetically', 'compensatory', 'alignmentscomputational']
# ['tmprss', 'fusion', 'erg', 'tumors', 'assay', 'fusions', 'ets', 'gene', 'multiple', 'prostate', 'specimens', 'variants', 'sensitive', 'cancer', 'variantsstudies', 'impure']
# ['splice', 'pmo', 'correction', 'ahx', 'conjugate', 'affinity', 'cpp', 'analogs', 'delivery', 'heparin', 'morpholino', 'arg', 'hydrophobicity', 'applications', 'uptake', 'correlation', 'peptides', 'efficiency', 'model', 'might', 'studiesredirecting', 'stereochemistry', 'phosphoramidate']
# ['vaccination', 'clearance', 'norovirus', 'mucosal', 'mnv', 'cells', 'immune', 'efficient', 'intestine', 'lymph', 'nod', 'intestinal', 'capsid', 'vaccinate', 'require', 'infection']
# ['antiviral', 'drug', 'optimal', 'perspective', 'treatment', 'public', 'control', 'will', 'scale', 'program', 'individual', 'health', 'take', 'strategy', 'situation', 'large', 'risk', 'interest', 'prevent']
# ['influenza', 'seasonal', 'humoral', 'cross', 'subtype', 'immunity', 'donors', 'avian', 'persons', 'vaccinate', 'frequency', 'vaccination']
# ['children', 'hbov', 'symptomatic', 'rtis', 'npas', 'asymptomatic', 'adults', 'bocavirus']
# ['disparities', 'racial', 'ethnic', 'social', 'plan', 'socioeconomic', 'pandemic', 'state', 'unite', 'attention', 'might']
# ['rhinovirus', 'genotypeglobal', 'indicate', 'novel', 'america']
# ['map', 'cost', 'project', 'interaction', 'plat', 'design', 'completion', 'pair', 'best', 'efforts', 'complete', 'fold', 'protein', 'thresholding']
# ['lysate', 'bacterial', 'influenza', 'inflammation', 'survival', 'mortality', 'superinfection', 'lung', 'host', 'aerosolize', 'ineffective', 'resistance', 'augment', 'excessive', 'pneumonia', 'cause', 'viral', 'induce', 'expose', 'inflammatory']
# ['peptide', 'nsclc', 'tumor', 'phage', 'cancer', 'target', 'drug', 'chemotherapies', 'doxorubicin', 'xenografts', 'liposomes', 'lung', 'mice', 'synthetic', 'cell', 'ligand', 'specimens', 'bind', 'normal', 'specifically', 'line', 'tissue']
# ['chikungunya', 'fever', 'biomarkers', 'growth', 'disease', 'patients', 'rant', 'cytokines', 'chemokines', 'factor', 'severe', 'plasma', 'severity', 'able', 'singaporean', 'analyze', 'tock']
# ['nss', 'rvfv', 'pkr', 'eif', 'host', 'suppression', 'transcriptional', 'downregulation', 'phosphorylation', 'protein', 'fever', 'replication', 'valley', 'function', 'inhibit', 'mrnas', 'mediate', 'kinase', 'induce', 'translation']
# ['market', 'thailand', 'food', 'bird']
# ['officinalis', 'medicinal', 'magnoliae', 'cortex', 'antioxidant', 'herba', 'plant', 'activities', 'antimicrobial', 'rhizoma', 'polygonis', 'murraya']
# ['schizophrenia', 'herpes', 'military', 'postdiagnosis', 'specimens', 'discharge', 'study', 'viruses', 'black', 'association', 'family', 'among', 'simplex', 'sera', 'members', 'larger', 'significant', 'hypothesis', 'type', 'pre']
# ['scientific', 'pandemic', 'preparedness', 'influenzaauthoratative']
# ['smallpox', 'monthly', 'historical', 'annual', 'transmission', 'clearly', 'season', 'report', 'reanalyzed', 'reanalysis', 'dataseasonal', 'calendar', 'mortality', 'spectral']
# ['chinese', 'journals', 'publication', 'databases', 'bibliographic', 'journal', 'preventive', 'epidemiology', 'medicine', 'literature']
# ['nagk', 'hongkongensis', 'argb', 'freshwater', 'temperature', 'hlhk', 'deinococcus', 'efflux', 'genome', 'mechanisms', 'habitats', 'adaptations', 'transporters', 'arginine', 'temperatures', 'fish', 'gastroenteritis', 'different', 'proteome', 'content', 'copy', 'adaptation', 'bacteria', 'reveal', 'acids', 'expression', 'encode', 'negative']
# ['pleural', 'mesothelioma', 'malignant', 'exposure', 'asbestos', 'pain', 'occupational', 'chest', 'involvement', 'thicken', 'peritoneal', 'spontaneous', 'history', 'life', 'vaginalis', 'tunica', 'sweat', 'rind', 'presentations', 'pericardium', 'palliation', 'multidisciplinary', 'mesothelium', 'mesotheliomas', 'mesotheliomamalignant']
# ['stockpile', 'drug', 'antiviral', 'treatment', 'resistance', 'pandemic', 'strain', 'outbreak', 'run', 'timely', 'level', 'population', 'onset', 'sensitive', 'resistant', 'plan', 'use', 'scale', 'size', 'wide', 'strategy', 'apply']
# ['dog', 'rabies', 'domestic', 'populations', 'canine', 'elimination', 'global', 'transmission', 'africa', 'throughout', 'dynamics', 'rabiesrabies', 'rabid', 'historic', 'trajectories', 'tanzania', 'realistic', 'carnivore', 'dangerous', 'uniquely', 'obstacle']
# ['gmo', 'detection', 'amplification', 'lamp', 'isothermal', 'dna', 'transgene', 'template', 'amplify', 'use', 'background', 'sensitivity', 'apply']
# ['hpai', 'vaccines', 'chickens', 'dna', 'needle', 'avian', 'ability', 'trivalent', 'vaccine', 'strain', 'protect', 'influenza', 'vaccination', 'injection', 'device', 'heterologous', 'elicit', 'adaptation', 'immunization', 'neutralize', 'evolve']
# ['cgmmv', 'read', 'caa', 'uag', 'uua', 'mottle', 'cucumber', 'insert', 'mosaic', 'wild', 'chimeric', 'type', 'green', 'infectivity', 'dengue', 'clone', 'construct', 'viruses', 'virus', 'recombinant']
# ['norovirus', 'hygiene', 'reduction', 'measure', 'outbreaks', 'towel', 'toilets', 'scout', 'outbreakcontrol', 'jamboree']
# ['kipyv', 'wupyv', 'respiratory', 'patients', 'saint']
# ['pulmonary', 'surfactant', 'pathology', 'molecule', 'properties', 'importance', 'upcoming', 'orientate', 'lungssurfactant', 'complexly', 'lung', 'player', 'repeatedly', 'nsclc', 'chromosomal', 'carcinomas', 'immunohistochemistry', 'surprise']
# ['atsbt', 'proatpsk', 'explants', 'atpsk', 'peptide', 'subtilase', 'root', 'proteolytic', 'cleave', 'precursor', 'culture', 'myc', 'subtilisin', 'precursors']
# ['boundaries', 'domain', 'prediction', 'biology', 'structural', 'predictions', 'computational', 'must', 'rather', 'predict', 'tool', 'protein']
# ['sensitivity', 'automate', 'dod', 'data', 'alert', 'visit', 'algorithms', 'baseline', 'improve', 'day', 'series', 'surveillance', 'increase', 'eds']
# ['recombination', 'recombinants', 'hiv', 'breakpoints', 'evolution', 'gene', 'envelope', 'constraints', 'influence', 'force', 'process', 'purify', 'within', 'act', 'relatively', 'selection', 'contribute', 'pathogens', 'dominance', 'pattern', 'predictable', 'paucity', 'distinctive', 'genome', 'recombine', 'randomness']
# ['avian', 'viruses', 'influenza', 'human', 'temperature', 'temperatures', 'airways', 'restriction', 'proximal', 'epithelium', 'glycoproteins', 'airway', 'chick', 'victoria', 'hae', 'ciliated', 'italy', 'residue', 'restrict', 'infection']
# ['health', 'public', 'classification', 'classifications', 'dimension', 'infrastructure', 'class', 'function', 'resources', 'determinants', 'multidimensional', 'settings', 'issue', 'ontology', 'activity', 'exist', 'capture', 'use', 'interventions', 'across', 'address']
# ['sim', 'rnai', 'inhibition', 'sirna', 'influenza', 'shrna', 'sirnas', 'target', 'inhibit', 'virus', 'interfere', 'vector', 'resistant', 'gene', 'long', 'therapy', 'term', 'antiviral', 'replicationrna']
# ['vivax', 'pvmdr', 'pvcrt', 'chloroquine', 'severe', 'symptoms', 'resistance', 'patient', 'level', 'plasmodium', 'patients', 'exclusively', 'mild', 'malaria', 'brazilian', 'amazon', 'transporter', 'increase', 'expression', 'clinical', 'magnetic']
# ['mother', 'child', 'workers', 'health', 'prevention', 'hiv', 'care', 'service', 'transmission', 'quality', 'vertical', 'skills', 'good', 'counsel', 'fear', 'provide', 'infect', 'lack', 'staff', 'women', 'system', 'failure', 'workloads', 'workload', 'unwilling', 'unavailability', 'semistructured']
# ['lassa', 'antitrypsin', 'glycoprotein', 'replication', 'virus', 'proteolytic', 'inhibit', 'precursor', 'adapt', 'cleavage', 'protease', 'process', 'variants', 'inhibition', 'site', 'variantsbackground', 'rrll']
# ['virhostnet', 'host', 'virus', 'network', 'interactions', 'redundant', 'knowledge', 'proteome', 'public', 'viral', 'integrate', 'management', 'new', 'interaction', 'rationalize', 'pbildb', 'networksinfectious', 'analytic', 'base', 'univ']
# ['rfam', 'families', 'cms', 'annotations', 'taxonomic', 'sequence', 'rna', 'http', 'majority', 'snornas', 'methodologies']
# ['rhinoviruses', 'respiratory', 'genotypic', 'diversity', 'enteroviruses', 'circulate', 'enterovirus', 'identify', 'evolution', 'picornavirusesrhinoviruses', 'otitis', 'picornavirus', 'recombine', 'generic', 'untranslated']
# ['hiv', 'dbs', 'assay', 'rtlc', 'copy', 'diagnosis', 'blood', 'quantify', 'cost', 'rna', 'dry', 'monitor', 'spot', 'log', 'real', 'rapid', 'clades', 'early', 'limit', 'settings', 'resource', 'across', 'fold', 'time', 'ultrasensitive', 'serially']
# ...
# ['tmv', 'phenanthroquinolizidine', 'alkaloids', 'configuration', 'activity', 'antiviral', 'tobacco', 'mosaic', 'introduction', 'compound', 'vivo', 'stucture', 'phenanthroquinolizidines']
# ['antibody', 'responses', 'neutralize', 'cell', 'influenza', 'expansion', 'monovalent', 'vaccines', 'pdm', 'vaccine', 'subtype', 'cells', 'relationship', 'pandemic', 'response', 'vaccination', 'vaccinebackground']
# ['households', 'quarantine', 'leave', 'pay', 'parent', 'work', 'take', 'access', 'compliance', 'school', 'time', 'financial', 'lose', 'resident', 'recommendations']
# ['condom', 'hiv', 'men', 'sex', 'interventions', 'msm', 'chinese', 'self', 'receipt', 'aor', 'prevalence', 'increase', 'trend', 'partner']
# ['tnf', 'lta', 'polymorphisms', 'genotype', 'ccl', 'infection', 'pandemic', 'case', 'severity', 'influenza', 'patients', 'associate', 'level', 'virus', 'control', 'association', 'illness', 'contribute', 'severer', 'phosphokinase', 'familial', 'urea']
# ['patent', 'complement', 'relate', 'trend', 'compound', 'immune', 'interest', 'discovery', 'trademark', 'macular', 'innateimmunity', 'chapter', 'diagnosis', 'research', 'office', 'intellectual', 'immunoassays', 'grant', 'various', 'rejection', 'publication', 'pathologies']
# ['clone', 'scfvs', 'clade', 'phage', 'selection', 'hiv', 'ebv', 'antigen', 'antibodies', 'reactivity', 'technology', 'peptides', 'scfv', 'transformation', 'hybridoma', 'strategy', 'library', 'anti', 'avoid', 'dna', 'neutralization', 'positive', 'variable', 'elisa', 'bind', 'generation']
# ['hygiene', 'wear', 'mask', 'face', 'practice', 'behaviors', 'public', 'season', 'avoid', 'japanese', 'influenza', 'personal', 'gargle', 'positive', 'crowd', 'wash', 'occasional', 'health', 'occasionally']
# ['faecium', 'swiv', 'probiotic', 'mdbk', 'enterococcus', 'cells', 'swine', 'defence', 'viability', 'influenza', 'treat', 'min', 'propagation', 'food', 'medium', 'porcine', 'inhibitory', 'virus', 'health', 'growth', 'line', 'direct']
# ['cells', 'cell', 'persistence', 'viral', 'mcmv', 'hcv', 'hiv', 'regulate', 'rheostats', 'anti', 'lcmv', 'exhaustion', 'infections', 'killer', 'mice', 'virus', 'mediate', 'pathology', 'act', 'infect', 'natural']
# ['influenza', 'admissions', 'intensive', 'excess', 'care', 'seasonal', 'aboriginal', 'icu', 'estimate', 'people', 'pregnant', 'australia', 'use', 'women', 'wales', 'rate', 'series', 'pandemic', 'epidemic', 'pdm']
# ['aav', 'upr', 'perk', 'scaav', 'fold', 'ire', 'pathways', 'vectors', 'transfer', 'modest', 'activate', 'gene', 'unfold', 'cellular', 'mediate', 'induce', 'stress', 'response', 'inhibition', 'activation', 'vectorsthe', 'metformin', 'endoribonuclease', 'vitro']
# ['hypoxia', 'metastasis', 'hif', 'regulate', 'metastatic', 'genes', 'target', 'induce', 'tumor', 'molecules', 'factor', 'microenvironmental', 'metastasishypoxia']
# ['keratitis', 'herpetic', 'therapy', 'gene', 'ocular', 'hsv', 'discuss', 'therapeutic', 'therapyocular', 'neovascularization', 'inherit', 'cornea', 'clip', 'strategies', 'research', 'blindness', 'assess', 'reality']
# ['canadian', 'communities', 'research', 'health', 'aboriginal', 'face', 'workshop', 'community', 'populations', 'indigenous', 'pandemic', 'collaborative', 'objectives', 'build', 'challenge', 'practice', 'outcomes', 'address']
# ['sbv', 'lamb', 'nss', 'tropism', 'vacuolation', 'schmallenberg', 'abort', 'virus', 'virulence', 'calve', 'experimental', 'cerebral', 'pathogenesis', 'neurons', 'naturally', 'synthetic', 'replicate', 'biology', 'system', 'develop', 'wild', 'culture', 'cell', 'useful', 'stillborn', 'porencephaly', 'passage']
# ['cavernous', 'uterus', 'partum', 'myometrium', 'hemangiomas', 'hemangioma', 'woman', 'thrombi', 'case', 'vascular', 'post', 'myometrial', 'gravid', 'examination', 'thrombosis', 'fresh', 'cesarean', 'endothelium', 'histological', 'pulmonary', 'section', 'report', 'rare', 'hemorrhagic', 'fatal', 'delivery', 'respiratory', 'transabdominal', 'thrombose', 'thromboplastin', 'thromboemboli', 'spongy', 'prothrombin']
# ['codon', 'usage', 'iav', 'bias', 'strain', 'pandemic', 'adaptation', 'composition', 'trna', 'pdm', 'mutational', 'comprehensive', 'pressure', 'host', 'selection', 'virus', 'different', 'influenza', 'orthomyxoviridae', 'developmentbackground', 'coa', 'base', 'suggest', 'thr', 'revisit']
# ['lrti', 'hospitalizations', 'pediatric', 'lrtis', 'infants', 'bed', 'year', 'care', 'age', 'burden', 'healthcare', 'acute', 'columbia', 'respectively', 'projections', 'british', 'due', 'olds', 'prevention', 'november', 'demand']
# ['apmv', 'cleavage', 'pathogenicity', 'chickens', 'site', 'mutant', 'duck', 'replication', 'old', 'paramyxoviruses', 'avirulent', 'syncytium', 'protein', 'parental', 'recovery', 'vitro', 'week', 'confer', 'recover', 'increase']
# ['pacific', 'territories', 'island', 'countries', 'pandemic', 'influenza', 'august', 'case', 'confirm', 'surveillance', 'tokelau', 'pitcairn', 'picts', 'email', 'report', 'gather', 'outbreak', 'illness', 'institute', 'regional', 'like', 'health', 'despite', 'world', 'tuvalu', 'niue', 'maritime']
# ['childhood', 'queensland', 'orchid', 'diary', 'cohort', 'ethics', 'gastrointestinal', 'birth', 'hospital', 'illness', 'observational', 'child', 'research', 'age', 'swab', 'dynamic', 'women', 'epidemiology', 'infectious', 'study', 'diseases', 'incidence', 'respiratory', 'children', 'pathogens']
# ['getah', 'virus', 'vidiscr', 'rapd', 'cdna', 'strain', 'isolate', 'discovery', 'polymorphic', 'novel', 'gene', 'amplify', 'method', 'random', 'sequence', 'structural', 'identification', 'protein', 'togaviridae']
# ['mzp', 'cap', 'rna', 'hce', 'guanylyltransferase', 'monophosphate', 'mizoribine', 'inhibitor', 'mrnas', 'inhibit', 'triphosphatase', 'impdh', 'guanine', 'novo', 'catalyze', 'impair', 'activity', 'agent', 'nucleotide']
# ['vocs', 'exhale', 'pulmonary', 'diseases', 'volatile', 'organic', 'copd', 'clinical', 'profile', 'asthma', 'accurately', 'patients', 'compound', 'systematic', 'diagnose', 'disease', 'tract', 'study', 'techniques', 'cancer', 'healthy', 'control', 'apply']
# ['gbv', 'hiv', 'disulfide', 'peptides', 'loop', 'entry', 'fusion', 'coinfection', 'terminus', 'interfere', 'bind', 'experiment', 'glycoprotein', 'viraemia', 'niche', 'loopa', 'imitation', 'coreceptor', 'termini', 'partly', 'flaviviridae', 'engagement']
# ['brain', 'proteobacteria', 'bacterial', 'hiv', 'odc', 'microbial', 'sequence', 'rrna', 'surg', 'implantation', 'rag', 'group', 'quantity', 'white', 'matter', 'cerebral', 'rna', 'diversity', 'human', 'immune', 'detect', 'aid', 'host', 'profile', 'variably']
# ['dpi', 'pig', 'saa', 'app', 'swine', 'serum', 'significantly', 'score', 'acute', 'concentration', 'influenza', 'swh', 'pasteurella', 'haptoglobin', 'piglets', 'coinfected', 'amyloid', 'crp', 'severity', 'phase', 'antibodies', 'reactive', 'protein']
# ['drip', 'positional', 'epitopes', 'bias', 'source', 'towards', 'class', 'antigens', 'skew', 'mhc', 'terminus', 'viral', 'products', 'degree', 'restrict', 'peptides', 'constitutive', 'conservationthe']
# ['caspase', 'bioenergetics', 'lung', 'tissue', 'amc', 'atp', 'activity', 'wistar', 'oxygenate', 'mem', 'asp', 'incubate', 'buffer', 'toxins', 'min', 'cleave', 'content', 'cellular', 'despite', 'monitor', 'rat', 'pathogens', 'urethane']
# ['ibv', 'chickens', 'lesions', 'republic', 'china', 'bronchitis', 'virulent', 'isolate', 'kidney', 'severe', 'deaths', 'day', 'people', 'old']
# ['mbds', 'mekong', 'trust', 'network', 'surveillance', 'basin', 'countries', 'threats', 'border', 'health', 'professionals', 'disease', 'across', 'pioneer', 'minister', 'memorandum', 'jointly', 'emulate', 'yunnan']
# ['quarantine', 'centuries', 'public', 'diseases', 'become', 'strategy', 'globalize', 'millennium', 'cornerstone', 'reemerging', 'plague', 'socioeconomic', 'careful', 'infectious']
# ['sequencers', 'information', 'global', 'technologies', 'laboratories', 'genome', 'public', 'share', 'generation', 'health', 'clinical', 'provide', 'spawn', 'responsethe', 'modernize', 'advancement', 'quicker']
# ['hbov', 'saudi', 'bocavirus', 'arabia', 'children', 'detect', 'tract', 'genotype', 'infections', 'respiratory', 'circulate', 'patients']
# ['hiv', 'apoptosis', 'sign', 'activation', 'ask', 'sensitize', 'ligation', 'immune', 'serum', 'excessive', 'accelerate', 'individuals', 'depletion', 'mechanism', 'pro', 'dendritic', 'undergo', 'induce', 'aid', 'envelope', 'circulate', 'chronic', 'death', 'become', 'prevent']
# ['tii', 'cells', 'lps', 'alveolar', 'culture', 'tnf', 'response', 'facs', 'rat', 'epithelium', 'type', 'primary', 'lung', 'stimulation', 'macrophages', 'immune', 'prior', 'level', 'report', 'increase', 'stimulationthe', 'blunt']
# ['tunnel', 'polymerase', 'structure', 'segment', 'ntp', 'sequence', 'polymerases', 'exterior', 'structural', 'template', 'species', 'residue', 'though', 'rna', 'composition', 'entry', 'residues', 'map', 'conserve']
# ['pcd', 'beat', 'ciliary', 'patients', 'qualitative', 'quantitative', 'gold', 'evaluation', 'standard', 'diagnosis', 'analysis', 'pattern', 'parameters', 'nasal', 'suspect', 'videomicroscopy', 'inconclusive', 'edge', 'dyskinesia', 'concordant', 'ciliated', 'nitric']
# ['age', 'mortality', 'breakpoints', 'pandemic', 'excess', 'kentucky', 'years', 'minimum', 'rat', 'sex', 'maximum', 'risk', 'unknown', 'year', 'statewide', 'kentuckybackground']
# ['membrane', 'reconstitution', 'proteins', 'model', 'phospholipid', 'reconstitute', 'activities', 'activity', 'protein', 'retain', 'composition', 'often', 'better', 'discuss', 'systems', 'nanodiscs', 'bilayers']
# ['rvsv', 'rabv', 'transsynaptic', 'retrograde', 'anterograde', 'vsv', 'tracer', 'neuron', 'connections', 'rabies', 'stomatitis', 'recombinant', 'neurons', 'vesicular', 'trace', 'virus', 'provide']
# ['ali', 'patients', 'pneumonia', 'inappropriate', 'nest', 'risk', 'development', 'antimicrobial', 'hospitalize', 'infectious', 'acute', 'injury', 'initial', 'factor', 'predict', 'pathogen', 'rochester', 'prehospital', 'pneumonias', 'pneumoniaintroduction', 'microbiologically']
# ['hcv', 'lfia', 'das', 'strip', 'new', 'anti', 'sandwich', 'serum', 'immunoassay', 'antibodies', 'lateral', 'sera', 'elisa', 'double', 'flow', 'plasma']
# ['hcv', 'curcumin', 'oxygenase', 'heme', 'inhibit', 'akt', 'erk', 'induction', 'dependently', 'replication', 'inhibition', 'protein', 'dose', 'expression', 'activities', 'hepatitis', 'hemin', 'aktalthough', 'anti', 'replicon']
# ['travel', 'restriction', 'land', 'air', 'restrictions', 'sea', 'transport', 'kong', 'hong', 'pandemic', 'mitigation', 'antivirals', 'hospitalization', 'strategies', 'model', 'influenza', 'china', 'peak', 'source', 'new', 'establish', 'regulate', 'virusbackground', 'retard', 'intrusive', 'arrivals', 'allow']
# ['versus', 'unsuspected', 'influenza', 'patients', 'respiratory', 'icu', 'icus', 'systematically', 'median', 'radiograph', 'sample', 'failure', 'screen', 'days', 'lower', 'chest', 'infiltrate', 'stay', 'localize', 'suspect']
# ['registry', 'icus', 'flu', 'french', 'icu', 'university', 'burden', 'geographical', 'line', 'screen', 'daily', 'cohort', 'occupancy', 'areas', 'exceed', 'bed', 'threshold', 'infect', 'hospitals', 'participate', 'weeks', 'poorly']
# ['pneumococcal', 'icu', 'patients', 'pneumoniae', 'cap', 'pneumonia', 'replacement', 'renal', 'admit', 'penicillin', 'mortality', 'severe', 'outcome', 'therapy', 'septic', 'adequate', 'reach', 'shock', 'susceptibility', 'acquire', 'failure', 'two', 'bacteraemia', 'antibiotherapy', 'thoracic']
# ['synthetic', 'genomics', 'biology', 'organisms', 'applications', 'biological', 'new', 'engineer', 'function', 'genomes', 'benefit', 'exist', 'systems', 'stir', 'satisfy', 'renewable', 'progressively']
# ['codon', 'bias', 'usage', 'dinucleotide', 'composition', 'content', 'rna', 'pressure', 'mutational', 'mononucleotide', 'viruses', 'nucleotide', 'genomic', 'synonymous', 'explain', 'translation', 'position', 'relative']
# ['renal', 'postoperative', 'mortality', 'transplant', 'liver', 'failure', 'rrt', 'replacement', 'recipients', 'preoperative', 'group', 'acute', 'therapy', 'cumulative', 'baseline', 'icu']
# ['mineral', 'oil', 'bioaerosol', 'andersen', 'agar', 'impactor', 'bounce', 'min', 'sample', 'aerosols', 'particle', 'plate', 'biostage', 'impaction', 'samplers', 'opc', 'impactors', 'enhancements', 'desiccation', 'stage', 'plat', 'aerosolize']
# ['sari', 'persons', 'hospitalize', 'kenya', 'guatemala', 'old', 'influenza', 'years', 'per', 'associate', 'case', 'healthcare', 'provincial', 'burden', 'national', 'severe', 'countries', 'base']
# ['hbz', 'htlv', 'tsp', 'ham', 'atl', 'patients', 'humoral', 'antibody', 'response', 'zipper', 'immune', 'serum', 'leucine', 'infect', 'responses', 'subtype', 'subject', 'basic']
# ['qtl', 'weight', 'loss', 'disease', 'variation', 'contribute', 'identify', 'genetic', 'host', 'induce', 'influenza', 'virus', 'collaborative', 'confound', 'phenotypes', 'replication', 'aspects', 'genetically', 'observe', 'environmental', 'outcomes', 'diverse', 'inflammation', 'pre', 'populations', 'correlate']
# ['asthma', 'hospitalize', 'patients', 'icu', 'likely', 'admission', 'influenza', 'pneumonia', 'among', 'pdm', 'persons', 'die', 'admit', 'pandemic', 'old', 'case']
# ['ssrs', 'genomes', 'repeat', 'genome', 'size', 'sequence', 'certain', 'virus', 'distribute', 'longer', 'strongly', 'simple', 'variances', 'sizebackground', 'repetitiveness']
# ['pkr', 'trna', 'nucleoside', 'modifications', 'activation', 'activate', 'tertiary', 'transcripts', 'trnas', 'phe', 'native', 'transcript', 'suppress', 'natively', 'modify', 'innate', 'intrinsic', 'ability', 'bovine', 'vitro', 'cellular', 'rna', 'yeast']
# ['unresectable', 'cryoablation', 'sorafenib', 'hcc', 'median', 'patients', 'stage', 'tolerability', 'treat', 'hepatocellular', 'combine', 'progression', 'months', 'advance']
# ['mtb', 'cba', 'secrete', 'cells', 'tuberculosis', 'expansions', 'mycobacterium', 'immunosuppressive', 'depletion', 'although', 'cell', 'infection', 'chronic', 'vivo', 'tim', 'mice']
# ['polyethylenimine', 'radiation', 'tlr', 'agonist', 'dose', 'irradiation', 'pei', 'survival', 'body', 'mediate', 'receive', 'agents', 'effect', 'toll', 'anti', 'weight', 'correlation', 'animal', 'application']
# ['malarial', 'disturbances', 'infection', 'immunological', 'countries', 'parasitic', 'malaria', 'immune', 'associate', 'drug', 'urbanization', 'overcrowd', 'ordinate', 'infectionmalaria', 'due', 'reemerging']
# ['vaccine', 'determinants', 'successful', 'developmentepidemiological', 'measurable', 'requirement']
# ['rule', 'classification', 'syndromic', 'automate', 'interpretability', 'macro', 'performance', 'micro', 'class', 'achieve', 'learn', 'laboratory', 'bay', 'classifier', 'veterinary', 'equal', 'base', 'experts', 'tree', 'decision', 'algorithm', 'high', 'methods', 'score']
# ['viral', 'sequence', 'sample', 'rna', 'ultra', 'threats', 'copy', 'low', 'full', 'prior', 'genomes', 'amount', 'independent', 'agents', 'complete', 'amplificationrna']
# ['mimetics', 'protein', 'hairpin', 'epitope', 'design', 'synthetic', 'grow', 'vaccinology', 'outer', 'antibiotics', 'crystal', 'biologically', 'ligands', 'motifs', 'structure', 'start', 'inhibitors', 'point', 'membrane', 'importance', 'fold', 'structural', 'wiley', 'sons']
# ['panad', 'pan', 'bonobo', 'vector', 'transgene', 'adenovirus', 'influenza', 'antigens', 'conserve', 'vaccines', 'antibody', 'paniscusamong', 'paniscus', 'npm']
# ['weather', 'extreme', 'water', 'events', 'outbreaks', 'waterborne', 'promed', 'relate', 'flood', 'report', 'spp', 'rainfall', 'georef', 'drought', 'diseaseglobal', 'alongside']
# ['kshv', 'falciparum', 'malaria', 'syndemic', 'cyto', 'basigin', 'mutual', 'sarcoma', 'kaposi', 'adherence', 'erythrocytes', 'aggressive', 'host', 'invasion', 'parasite', 'endemic', 'relationship', 'implications', 'infect', 'interactions', 'unexplored', 'triangulation', 'pathobiological', 'parasitemia', 'neoplasm', 'merozoites']
# ['nols', 'nucleolus', 'nucleolar', 'noa', 'localization', 'direct', 'capable', 'egfp', 'three', 'residues', 'mammalian', 'cluster', 'sequence', 'conserve', 'amino', 'protein']

# %%
def sort_tf_idf_vector(coo_matrix):
    """Sorting the tf-idf vector"""
    tuples = zip(coo_matrix.col, coo_matrix.data)
    return sorted(tuples, key=lambda x: (x[1], x[0]), reverse=True)

def extract_topn_from_vector(feature_names, sorted_items,topn):
    """get the feature names and tf-idf score of top 20% words"""
    
    sorted_items = sorted_items[:topn]  #collect only topn items from vector

    topnwords = []
    
    # index of word, respective tf-idf score
    for idx, score in sorted_items:
        
        #append the sorted words
        topnwords.append(feature_names[idx])
   
    return topnwords

# %%
results
# Out:
# ['pneumoniae patients comorbidities pneumonia common infections die king jeddah crepitations abdulaziz saudi mycoplasma chart culture immunocompromised university infants',
#  'inflammatory oxidant presume nitric oxide contribution lung anti evidence tract phagocyte peroxynitrite oxidations comprehensively',
#  'surfactant deficient glycoconjugates organic lipids microorganisms surface contribute abnormal lung express macrophages epithelial variety antigens phosphatidylinositol oligomerized mixtures genitourinary exocrine',
#  'lung diseases role inflammatory tone endothelin',
#  'pneumovirus epithelial gene infectionrespiratory pvm chemoattractant incompletely responses subfamily paramyxoviridae unravel rsv rodents',
#  'trs discontinuous strand subgenomic leader body rna transfer synthesis sequence trss minus template end derive',
#  'transfuse haemoglobin improve ill critically normal level blood rbcs outcomerecent care rct',
#  'symposium medicine intensive care emergency international tutorials seminars enthusiasm con',
#  'heme oxygenase monoxide pulmonary carbon inflammatory anti stress virtue medicineheme ferrous cytoprotection cigarette bilirubin isozyme upregulation smoke rejection nitrogen',
#  'rods data surveillance health send real algorithms public time apply syndrome systemthis sales olympics lease complaint chief warehouse utah',
#  'antizyme frameshift yeast pombe nematodes polyamine feedback frameshifting event translational require',
#  'hnrnp rna mhv mutant synthesis ribonucleoprotein nuclear cytoplasm cytoplasmic replication cellular viral mrna inhibition',
#  'uba domain interact proteins eleven proteinsthe polyubiquitin play reticulocyte lysate',
#  'microtubule vaccinia centrosome microtubules cytoskeleton fashion virus intracellular infection proteins map reorganize iev functionwe',
#  'multi infections array retrovirology viral viruses pcr detect microarray diagnostic virus profilesthere drawbacks dna human readouts faceted many reactivation fight hundreds chip versatile',
#  'ill critically hsv pathogenicity pli lungs normal permeability min simplex herpes patients isolation',
#  'vaccination ring contact smallpox trace sufficient case infectiousness logistics network awareness surveillance assume quickly stochastic mass capacity per vaccinators',
#  'hmyh repair toxic cells dna expression endogenous oxygen hnth lesion excision analysis toxicity oxidative condition blot perform enzymes cell',
#  'alkb domains methylating ptgs plant homologues like rna protect eukaryotes domain viral repair strand genomes map unmethylated phylogenomic pesticides oxoglutarate methylcytosine methylated methyladenine',
#  'legislation laws power emergency patchwork impediment commonwealth emerge saw jurisdictional',
#  'lactis heterologous protein yield production secretion lab proteolysis grade bacterium optimization proteins produce food conformation cytoplasmic size discuss',
#  'signature hts species transfer signatures dna genomic genome horizontal recipient detect look local short propose slide signaturehorizontal prokaryote prokaryotes influenzae',
#  'probe hybridization single deletions complementary insertions oligonucleotide base atm specificity substitutions nucleotide properties mutational microarray resequencing insertion microarrays',
#  'lse testis acetylesterase adult sialic human encode amino specific testisusing spermatogonia spermatogenic spermatocytes developmentally compartmentalization',
#  'pancreatitis mast pain chronic mcdm painful cells vff painless abdomen pancreatic compare pathogenesis humans mice sensitive',
#  'recombination host rate genomes frequency virus frequent single viral multi cycle viruses infectionviral everyday cauliflower replication genome cellular',
#  'pseudoknots torsional mrna frameshifting restraint jacobs dinman prf ribosome ribosomal position model twist',
#  'consensus errors shuffle synthetic population mismatch dna fluorescent fragment iterations gfpuv clone correct',
#  'rna quality metrics integrity rin microcapillary expression classifiers assessment electrophoresis user highly standard gene independent differences traceswhile repositories optional',
#  'frameshift cfmv prf minimal reporter cocksfoot yeast mottle translation replicase termination site dual signal downstream',
#  'fund health public program policy australian continue national future voice unsystematically tga overseas inconsistencies election competencies budget abelson',
#  'module geographic gideon comprehensive web base resource medicine medicinegideon write disease design informatics syndromic interactive graph',
#  'globalization health social access journal matter effect economic subject open wellbeing victory successes strive predilection pertain liberalization interconnectedness hurt healththis geography exemplify debut cheer benchmarks',
#  'recombination rna homomolecular system universal homologous comparison viruses new virus structural recombinationat heteromolecular obtain till brome bmv',
#  'reovirus protease serine uncoating proteases replication independent promonocyte pma inhibitor presence elastase ala acid proteolysis cells cysteine enteric neutrophil vesicular neutrophils replicate ards capacity infection facilitate treat agents subviron',
#  'lna methyl rna duplex nucleotides stabilities lnas separate lock terminal nucleotide least thermodynamic',
#  'draft quality signature sequence nns sap prediction genomes dna target finish error high signatures coverage simulations',
#  'epitopes ontology immune relate information iedb intrinsic concepts capture description database epitope class antigens pathogens semantics reactivitiesbackground emerge',
#  'genes atlantic actin salmon gapdh reference fish rrna smoltification pcr qrt calculations rank six adult evaluation encode real individuals',
#  'copd hmpv smokers patients exacerbations metapneumovirus stable sputum nasal lavage without',
#  'globalization project',
#  'cancer attributable fraction japanese awareness factor risk lifestyle population general men consider cause tend women candidates subject among',
#  'lamp templates precipitation nucleic pei visual device probe poct emit precipitate oligo color detection minute amount cationic amplicon',
#  'drug china abuse hiv aid policies illicit idu needle harm departments government injection past problems users reduction prevention local central program voluntary unpublished triangle smuggle',
#  'wnv humanize monoclonal neutralize nile antibodies antibody therapeutic supplementary west mice iii version domain dose surface',
#  'health local workers duty public willingness pandemic departments perceptions response perception toward multivariate report event influenza threat',
#  'hcps care duty professional obligations sars responsibilities ethics right ought health aftermath cod press issue communicable severely risk pandemic expose expect outbreaks paper outbreak systems provide',
#  'egcg ecg egc cancer line suppress tea gallate catechin ovarian growth cell untreated cells prostate gender',
#  'exacerbation markers severity copd exacerbations level variables iii patient dioxide obstructive study arterial carbon breathe namely meta weak july event change criteria manner consistent chronic pulmonary',
#  'ssh microarray assay cdna hepatoma differentially subtract genes expression transcriptomes low amplicons regular profile tedious combination modify inefficient high original transcripts pair express clone approach directly genomic',
#  'immunomic immunomics functional technology genomics microarray scientific challenge responses vision rewardsthe immunonic envision coherent allergies addressable computation big speculate',
#  'outbreaks smallpox median generations case america north europe index diagnose generation war initial review publications correctly library pattern hospitalize',
#  'definitions case shd lhd precision reliability examples surveillance robin revision check departments round health format list report predictive criteria sensitivity value',
#  'vap units intensive pneumonia hospital oropharynx controlventilator care mortality money colonize save',
#  'enterovirus sarawak outbreaks human malaysia sentinel throat mouth foot swab hand circulate outbreak surveillance region yearsbackground vesicle cyclical isolate',
#  'vsv growth attenuation vaccines attenuate virus model link engineer position alter live wild establish viruseslive nonsegmented generalization rearrangements manipulations genome mechanisms overexpressing hijack change',
#  'sirnas rnai delivery pei sirna interference intact organs tumor systemic target application promise systems vivo',
#  'oocyte genes maturation ovulation regulation vitellogenesis preovulatory exhibit ovarian cluster differentially time analysis trout slc rainbow aqp adam expression ovary fish dramatic cxcl post ace pattern use',
#  'epiflex locations model disease epidemics object contact phenomena characteristic computer within diseases system variety field phase better individuals epidemic define worthwhile superspreading multimodality inhabit epiflexbackground compression data spread result',
#  'test genetic newborn incorrect cftr newborns sample decode liquid screen target genotyped correctly platform call step state plx multiplexing multicode',
#  'frameshifting antisense orf shift site ribosomal frame read induce downstream translation locate frameshiftingprogrammed divert mechanism uga',
#  'recode frameshifting solfataricus fucosidase fuca archaea split gene translational full expression events program length',
#  'helicases rna encode orfs viruses strand genomes hiv ability surmise replicationviruses obligatorily devoid replicative',
#  'mimox epitope phage mimotopes map tool display section web base exist convenient embed consensus research native service view online access evaluate utilize community',
#  'fgf remyelination demyelination chronic mice oligodendrocyte cuprizone demyelinate endogenous chronically regeneration progenitor removal typically exhibit wild remyelinated remyelinate oligodendroglial nonlesioned',
#  'resequencing entries detail sequence automate pathogens information databases algorithm assay call microarray identification analysis pathogen unassisted microarraysthere',
#  'anticodon formula position text mcm loop see wild trna simulations simulation stem type modify mrna dynamics',
#  'probe oligonucleotide quencher endo linker rigid helper endonuclease end fluorescent substrate efficiently strand',
#  'ethical framework plan pandemic decision hospitals reflection ethics influenza guide make health help paper outbreak hospital vet tell stakeholder',
#  'patients olb ards biopsy pathological stage alteration diagnose rate early treatment immunocompromised complication mortality oxygen retrospective diagnostic survival distress open hospital mean',
#  'host pathogens associations multi analyse viruses indices pattern selective plant test distribution evolution specialisation',
#  'trace effectiveness contact effective proportion mouth foot smallpox emerge variability sars delay yet general time consider iterative brink',
#  'delay country travel source travelers region epidemic pandemic chance risk flight border pharmaceutical time interventions infect prevent screen influenza momentum minimally exit spread',
#  'antibody ebola neutralize macaques challenge monoclonal rhesus protect virus infection fail dose monkeysprophylaxis',
#  'organizational public alberta health inter preparedness network systems institutional design agency tie fund threats canada level prepare environmental components study',
#  'dysfunction cognitive mechanisms illness critical resolution brain markers associate influence transmitter therapeuticscognitive anticholinergic pathophysiologic neuro',
#  'procat microarrays protein approach microarraysprotein artifacts signal many',
#  'computational positional gaba cluster mammalian improve site subunit regulatory bind robustness predictions predict receptor accuracy gene experimental tfbs pharmacologically neurotransmitter imperfectly genesunderstanding',
#  'farm reproductive number hpai commercial outbreaks poultry eradicate avian transmissibility close pathogenic outbreak control estimate therefore influenza',
#  'plan pandemic influsim influenza tool software operate public design preparedness optimal health model apply produce operability influsimbackground generality computers administrations sickness realism',
#  'honey defences bee apis insect immunity social pathways individual pathogens orthologues melliferasocial coevolved',
#  'elad ubiquitin ulp senp clan deubiquitinating coli protease ubls hydrolases homologs eukaryotes proteases eukaryotic specific strain pathogenic ubl sulfatase ssel',
#  'ceacam bind ile ceacams residues bacterial pathogens gln domain human receptor model mutations target molecules distinct structural site tyr rei meningitidis intraspecies igv',
#  'iris syndrome infectious manifestations treatment reconstitution opportunistic art burden initiate immune underlie therapy inflammatory optionsthe exuberant condition common',
#  'influenza species viral surveillance genotypes esi pcr analysis infer mix subtypes mass emergence circulate global avian rapid identification evolution spectrometrybackground base identify isolate',
#  'transmission parameters fmd farm mouth foot epidemic great estimate proactively mcmc cull britaindespite britain',
#  'pvm macrophage mip mouse rodent line virus cell raw proinflammatory titers replication synthesis pneumonia inflammatory pneumovirinae linepneumonia',
#  'exercise tabletop departments health preparedness participate conduct public design emergency emergencies evaluation local strengths lessons state develop learn assess performance efforts action threatsbackground partnership manmade logistically',
#  'affymetrix annotation transcript probesets probeset level gene expression array refine interpretation microarray standard link protein databackground',
#  'trx redox extracellular thioredoxin disulfide receptor signal ligand cytokine surface interactions oxidoreductase catalytically catalyst identify mechanism',
#  'isg ubiquitin usp dub ubls proteases isot proteasome conjugate protease utilize family might therefore ubp promiscuous newcomer isopeptidase innocuous deubiquitinasesbackground deconjugating',
#  'melt mutation mutations scan sample mismatch screen enzymatic genetic dna pcr contain technology biology enable position cancer real rapid surveyor',
#  'coil helical parasite malaria vaccine peptides antibodies native sera candidates peptide active select rapid identification motifto erythrocytic',
#  'flugenome reassortment lineages genotypes nomenclature web influenza segment genotype viruses evolution tool virusinfluenza modalities interrogate',
#  'pharmaceutical stockpile pandemic antiviral influsim height reduction plan interventions contact drug wave measure intervention peak non much even epidemic influenza protraction overtax win',
#  'vaccines dna protozoan parasites advance new leishmaniasis curiosity challengesover chagas challenge',
#  'household reproduction number estimate track households simulations infect outbreak individual time define estimator epidemicreproduction emerge transmission play method',
#  'responses cell cells antiviral cytomegalovirus mcmv early promote accelerate ability killer control dendritic cytokine help ifn innate natural activation contribute cytomegalovirusunderstanding congenic cdcs viral production',
#  'fair poultry powder county contamination box pathogen light participants exhibit venue surreptitiously',
#  'apobec perv endogenous pig retrovirus human transmission restriction anti exogenous zoonotic innate inhibition xenotransplantation thwart hypermutations gthe fortify dominantly',
#  'hpai tuva russia pathogenic duck sera virus vaccines model sensivity quinghai mld ivpi characterize hypercytokinemia huge epizooty adamantanes occur',
#  'rna pseudoknots structure fold prediction heuristic map pseudoknot approach foldingpredicting thermodynamics historically many neglect flexibility',
#  'conjugate arginine correction toxicity oligoarginine splice uptake activity concentration cpp residues cellular pmo',
#  'save genomics world view scourge milstein intricacies grand award functional advent cellular want excite change lose',
#  'electrospray tnt ionisation cleavable conjugate esi pna probe nucleic tandem peptide hybridization mass acid synthesis',
#  'hax utr pol hairpin element transcriptional regulatory bind post expression polymerase regulation mrna protein polyadenylation dna carcinogenesis form',
#  'gpg global health concept initiatives gpgs promote goals development pose policy traditional conclude general paper apply define consider rhetoric potentialthe overstretch mobilisation mdg',
#  'sequelae survivors paediatric psychological physical intensive care quality life original parent study report seem determine treatment',
#  'cgs sequence genome insertions snps element detect mutations bacterium deletion comparative one accuracy present resequenced resequence nimblegen lambda kohara',
#  'hiv vaccines groupthe enterprise directions',
#  'dengue proteasome host fever tac replication upregulated genes pathway line ubiquitin gene expression response viral microarray infection throughput ifn quantitative cell blood viperin seriousness alln overexpressed',
#  'ceacam cea family gene immune ceacams dog evolution carcinoembryonic receptors canine proteins pathogens species purify cod bear relate selection mrna domain complete antigen activation specific regulate tremendous',
#  'nucleolus nucleolar nucleus ribosomal nucleoplasm nuclear ribosome synthesize rnas activity cycle proteins polymerase domain cell regulate',
#  'banaba glucose pgg activity extract uptake scientists lagerstroemin lagerstroemia corosolic adipocytes insulin chen responsible water anti transport identify compound components exhibit different model',
#  'ship serial communities reproductive interval maryland influenza number populations epidemic days statements pandemicbackground nonparametric enclose method',
#  'surfactant trials days failure children interval confidence mechanically ventilate acute ventilator respiratory randomize exogenous difference mortality enrol reduce',
#  'cross avian transmission range human influenza humansinfluenza humans species waterfowl fulminant',
#  'triage critical care plan recognise justice distributive contingency cohorting casualty careworst candid facility faceted transparent planners',
#  'health outbreak avian turkey van influenza service dogubeyazit integrate experience animal coordination personnel coordinate surveillance preparation region epidemic first interview control care public play months human national plan management case role lack',
#  'sentinel influenza europe activity season weeks spread peak report clinical match across east west south north winter eiss eight gps',
#  'sepsis difficulties campaign procedures survive sepsisthe proposals promptly pragmatism formalize',
#  'sepsis vector luc vectors luciferase clp gene ards alveolar immunostaining harvest induce transduction simian immunoassay rat vivo detection light double evaluate expression pulmonary',
#  'transfectants glycosylation dcat receptor virus moloney mcat dunni cytopathicity ecotropic syncytium mouse variant spl nih friend entry mlv env',
#  'frameshift tar initiation translation hiv efficiency alter rate stimulatory mrna ribosomes pkr luciferase change rna structure',
#  'sss taiwan surveillance syndromic system march illnesses emergency nationwide team spike real disease systems physicians syndrome establish department public like hospitals infectious international start health outbreak better control two',
#  'reactivity ctl cross tcr cell similarity amino biochemically acid identity model extent epitopes peptides diverse recognition peptide field recognize able',
#  'hrv rhinovirus qpm divergent strain detect members hrvs polyprotein silico deletions clinical species distinguish genus call six frequently yet feature hospital individuals analyse shortest footprints artis antigenicity previously',
#  'ali pmn apoptosis lung epithelial injury hypotheses neutrophil recruitment cell interfere therapeutic rnasin pathomechanisms morbid small mind fas',
#  'rna selection crossover recombinants recombination rnas acceptor affect recombinant site rate repeat drive',
#  'epigrass network model simulation construction task complex simulate software epidemiological facilitate epidemic tool workflow parameterization networksbackground daunt',
#  'lacv monkey rhesus cns crosse mice olfactory replicate pfu intranasally via titer infect neurons nasal immunogenicity inoculation infectivity encephalitis neutralize animal strong',
#  'tail terminal disorder intrinsically domain phosphoprotein structure fold nucleoprotein resonance complex consist induce sit virus region unfoldedmeasles themononegavirales themeasles heteronuclear',
#  'vehicles behaviors raw know modes attitudes practice poultry hygienic information transmission touch meat socioeconomic compliance animals knowledge food handle perceive avoid',
#  'viruses season evolution influenza period complete strain observe glycosylations denmark genome circulate study characterise knowledge site influence lineages prevalent genetic europe human genomes especially',
#  'duty profession consent presume participants risk argument choose hcws inform care medical say dentists justify moral provide occupational would treat diseases whether education physicians train problem aid certain level protective',
#  'feed shake methanol flasks batch pastoris aox collagen solution wireless production control apply optimization starvation pichia fermentation monitor pulse human promoter continuous example addition cost',
#  'hmgb activate endogenous alarmin function immune inflammatory infectious release injury molecules pathogens signalingwhile restorative milieu constituents archetypical alarmins recent condition',
#  'translation orf protein ires term vitro initiation rna system norovirus enteric bovine capsid like process detect follow epitope synthesis genomic sequence encode',
#  'household influenza index households secondary randomize attack ratios visit trial laboratory subject confirm interventions contact hygiene pharmaceutical home mask differ face members hand hours case',
#  'emerge infectious estimation time real diseases number case epidemiological bayesian significance transmissibility change standard statistical worldwide surveillance influenza violations observables bound allocations humans methodology introductions',
#  'detectiv normalization visualization software offer test tool datadna',
#  'fmdv silkworm vaccine subunit fmd baculovirus animals mouth foot bovine traditional expression develop dose hnk economical cha workshop vaccinebackground safer hoof dilute',
#  'mix contact trace network nod epidemic disassortatively disassortative assortatively assortative efficacy dynamics connect pattern epidemics',
#  'plan practice general framework appraise health influenza pandemic guide care available environment domains address five sketchy managerial haddon grey collaborations identify',
#  'stress apoptosis yeast apoptotic degradation pcd fragmentation induce death oxidative rnas ribosomal expose depend cell yeastorganisms yca respire metacaspase hyperosmotic',
#  'host evolve virus metabolism substitution viral transmit new symptoms contribute vpg spill radically passages expressionviruses epistatically allow usual fix ancestral exacerbate',
#  'hmpv rhmpv deletion attenuate metapneumovirus hamsters replication candidate genomic alter polymerase growth live transcription vivo complex hamstersbackground vitro vaccine',
#  'mucosal breakdown tlrs epithelial lead inflammation development innocent controversy bystander epithelium activation inflammatory intestinal toll barrier kidney determine injury central state work',
#  'ubiquitination cvb ubiquitin proteasome viral replication coxsackievirus protein apparent titers modification degradation function polymerase regulation inhibition role translationally coxsackieviral decrease cardiomyocytes mechanisms',
#  'mask wear respirators protection personal home imperfect aerosol exposure general volunteer type surgical make face degree healthy',
#  'oct cancer lung stem renew expression sirna like marker cells self treatment maintain properties spheres ribose prominin parp paclitaxel cisplatin chemoradiotherapy chemoradioresistant',
#  'piglets genes rotavirus regulate villous enterocytes microarray germ tip free infect virulent mucosal supplementary transport material expression cluster ifn regulation protein villus scrap rotavirusgerm jejunum',
#  'staff enteric ccc illness centre child manage cccs health challenge officials public experience guidance outbreaks focus decisions care assist risk action',
#  'divergence subtype substitution time rate clock date ago estimate researchers viral subtypes sequence zeroth triplets',
#  'lps tlr antagonists shock gram septic cause sepsis bacteria release clinical cytokines treat negative death inflammatory malfunction diseasessepsis blockage amphipathic receptor',
#  'dengue mip cytokine ifn severity patients manifestations mild associate mcp csf disease multiplex severe clinical cytokines contrast profile increase',
#  'species discovery curve virus human viruses new viruseson undiscovered extrapolate generate',
#  'selection alignment alignments frame read fix explicitly bias overlap inference run complicate uncertainty estimation accuracy integrate cod mutation genomes statistical one appear',
#  'sequence kong hong seasonality influenza nai syd mos season viruses elsewhere mutations resistance migration location different naturally neuraminidase continue may date relatively circulate',
#  'macrophages lung lungs neutrophils pandemic influenza virus similarities infect viruses infection mice immune pathogenic potentially mouse inflammatory micefatal',
#  'psgs selection genes positive enrich evidence mammalian evolution perception mammals power genome specific scan six additional wide previous testes taste nonselection genomesgenome fdr eutherian enrichments chemosensory',
#  'nanofluidic digital algorithm copy utilize variation number mathematically devicecopy',
#  'wnv climate scenarios simulate larviciding geosimulation crow forecast system nile mosquitoes west simulation measure place vector agent appropriate multi management map populations develop dynamics select interactions model systems visualisation roost quebec',
#  'medicine alternative aid sessions aidsimpact asia session cultural actors retroviral hiv africa meet settings insights resource poor live therapy senegal marseille legitimacy',
#  'reassortant genetic viruses parent interlineage diversity reassortment hpai emergence dynamics influenza reassorted onward indonesiah diversify humans phylogeography parsimony jakarta transmission strain',
#  'endothelial gammaherpesvirus cells viability cyclin lysis infection infect gammaherpesviruses lytic cell viral expression replication continue extend source virus surface provide neoplasms burkitt adherent production primary characterize',
#  'begomoviruses codon usage bipartite old world synonymous ones genes bias worlds usages monopartite',
#  'rfviia dah intrapulmonary administration vii case haemorrhage thrombotic bleed procedure diffuse complications alveolar icu observe activate two recombinant tachypnea',
#  'upr pfts pft mapk toxins defenses unfold response pathway bacterial activation xbp ire arm activate loss protective since',
#  'shrews parasites immune tissue wald haemolymphatic effectively lymphatic respond adults adult breed natural wild animals bring depletion common composition function may plasma sorex shrewbackground mat longevity lifespans immunosenescence',
#  'determinant heteroclitic ctl engineer subdominant basis enhancement substitution cell responses escape stability epitope prevention complex wildtype determinanthigh enhance pmhc histocompatibility',
#  'hcv hiv hepatic liver intra specific cells individuals infect bystander mono biopsies lymphocytes responses',
#  'hfs diagnosis hypofibrinogenemia multiorgan hemophagocytic failure case due therapy syndrome thrombopenia hypertriglyceridemia hyperferritinemia hlh hemophagocytosis bicytopenia sixteen reactants',
#  'copy number digital array nanofluidic sample breast gene variations dna difference use technology capable techniques throughput cancer twofold',
#  'phe hospitals staff train hospital preparedness emergency china survey management stockpile capacities medical could valid four demographic status capacity relate plan community systems laboratory drug',
#  'wasp ichnovirus ascoviruses ascovirus ichnoviruses genomes lateral wasps symbiogenesis ichneumonid virions dna evidence transfer particles proteins passive molecular replicate also evolution symbiogenesisbackground',
#  'immunity exist pre ebola vaccine nab bal pei bypass ifn oral adenovirus nasal compromise mice survive reduce vaccinate cells',
#  'apm respiratory pneumonia screen reportedly mimivirusacanthamoeba',
#  'allocation',
#  'psychological distress zone horse industry high outbreak disease equine population respondents income level australia whose measure study prevalence experience people first source live greater link collect',
#  'socs ifn stat induction signal type viral jak influenza phosphorylation expression viruses dependent deficient impair protein suppress cells action gene interferon response',
#  'ifn ads adenoviral tlr splenic cytosolic mdcs response mice hypersensitivity adenoviruses myeloid irf endosomal induce lps vivo toxic production signal side kinase recognition induction type',
#  'hses admission vasopressor infusion hours upon early patients shock mmol markers resuscitation hypotension encephalopathy platelet edema neurological diagnosis count enzymes fluid',
#  'pair fold rna base pfold thermodynamic predict probability structure currently conserve smoothen rnaalifold petfold incorrectly energetically compensatory alignmentscomputational',
#  'tmprss fusion erg tumors assay fusions ets gene multiple prostate specimens variants sensitive cancer variantsstudies impure',
#  'splice pmo correction ahx conjugate affinity cpp analogs delivery heparin morpholino arg hydrophobicity applications uptake correlation peptides efficiency model might studiesredirecting stereochemistry phosphoramidate',
#  'vaccination clearance norovirus mucosal mnv cells immune efficient intestine lymph nod intestinal capsid vaccinate require infection',
#  'antiviral drug optimal perspective treatment public control will scale program individual health take strategy situation large risk interest prevent',
#  'influenza seasonal humoral cross subtype immunity donors avian persons vaccinate frequency vaccination',
#  'children hbov symptomatic rtis npas asymptomatic adults bocavirus',
#  'disparities racial ethnic social plan socioeconomic pandemic state unite attention might',
#  'rhinovirus genotypeglobal indicate novel america',
#  'map cost project interaction plat design completion pair best efforts complete fold protein thresholding',
#  'lysate bacterial influenza inflammation survival mortality superinfection lung host aerosolize ineffective resistance augment excessive pneumonia cause viral induce expose inflammatory',
#  'peptide nsclc tumor phage cancer target drug chemotherapies doxorubicin xenografts liposomes lung mice synthetic cell ligand specimens bind normal specifically line tissue',
#  'chikungunya fever biomarkers growth disease patients rant cytokines chemokines factor severe plasma severity able singaporean analyze tock',
#  'nss rvfv pkr eif host suppression transcriptional downregulation phosphorylation protein fever replication valley function inhibit mrnas mediate kinase induce translation',
#  'market thailand food bird',
#  'officinalis medicinal magnoliae cortex antioxidant herba plant activities antimicrobial rhizoma polygonis murraya',
#  'schizophrenia herpes military postdiagnosis specimens discharge study viruses black association family among simplex sera members larger significant hypothesis type pre',
#  'scientific pandemic preparedness influenzaauthoratative',
#  'smallpox monthly historical annual transmission clearly season report reanalyzed reanalysis dataseasonal calendar mortality spectral',
#  'chinese journals publication databases bibliographic journal preventive epidemiology medicine literature',
#  'nagk hongkongensis argb freshwater temperature hlhk deinococcus efflux genome mechanisms habitats adaptations transporters arginine temperatures fish gastroenteritis different proteome content copy adaptation bacteria reveal acids expression encode negative',
#  'pleural mesothelioma malignant exposure asbestos pain occupational chest involvement thicken peritoneal spontaneous history life vaginalis tunica sweat rind presentations pericardium palliation multidisciplinary mesothelium mesotheliomas mesotheliomamalignant',
#  'stockpile drug antiviral treatment resistance pandemic strain outbreak run timely level population onset sensitive resistant plan use scale size wide strategy apply',
#  'dog rabies domestic populations canine elimination global transmission africa throughout dynamics rabiesrabies rabid historic trajectories tanzania realistic carnivore dangerous uniquely obstacle',
#  'gmo detection amplification lamp isothermal dna transgene template amplify use background sensitivity apply',
#  'hpai vaccines chickens dna needle avian ability trivalent vaccine strain protect influenza vaccination injection device heterologous elicit adaptation immunization neutralize evolve',
#  'cgmmv read caa uag uua mottle cucumber insert mosaic wild chimeric type green infectivity dengue clone construct viruses virus recombinant',
#  'norovirus hygiene reduction measure outbreaks towel toilets scout outbreakcontrol jamboree',
#  'kipyv wupyv respiratory patients saint',
#  'pulmonary surfactant pathology molecule properties importance upcoming orientate lungssurfactant complexly lung player repeatedly nsclc chromosomal carcinomas immunohistochemistry surprise',
#  'atsbt proatpsk explants atpsk peptide subtilase root proteolytic cleave precursor culture myc subtilisin precursors',
#  'boundaries domain prediction biology structural predictions computational must rather predict tool protein',
#  'sensitivity automate dod data alert visit algorithms baseline improve day series surveillance increase eds',
#  'recombination recombinants hiv breakpoints evolution gene envelope constraints influence force process purify within act relatively selection contribute pathogens dominance pattern predictable paucity distinctive genome recombine randomness',
#  'avian viruses influenza human temperature temperatures airways restriction proximal epithelium glycoproteins airway chick victoria hae ciliated italy residue restrict infection',
#  'health public classification classifications dimension infrastructure class function resources determinants multidimensional settings issue ontology activity exist capture use interventions across address',
#  'sim rnai inhibition sirna influenza shrna sirnas target inhibit virus interfere vector resistant gene long therapy term antiviral replicationrna',
#  'vivax pvmdr pvcrt chloroquine severe symptoms resistance patient level plasmodium patients exclusively mild malaria brazilian amazon transporter increase expression clinical magnetic',
#  'mother child workers health prevention hiv care service transmission quality vertical skills good counsel fear provide infect lack staff women system failure workloads workload unwilling unavailability semistructured',
#  'lassa antitrypsin glycoprotein replication virus proteolytic inhibit precursor adapt cleavage protease process variants inhibition site variantsbackground rrll',
#  'virhostnet host virus network interactions redundant knowledge proteome public viral integrate management new interaction rationalize pbildb networksinfectious analytic base univ',
#  'rfam families cms annotations taxonomic sequence rna http majority snornas methodologies',
#  'rhinoviruses respiratory genotypic diversity enteroviruses circulate enterovirus identify evolution picornavirusesrhinoviruses otitis picornavirus recombine generic untranslated',
#  'hiv dbs assay rtlc copy diagnosis blood quantify cost rna dry monitor spot log real rapid clades early limit settings resource across fold time ultrasensitive serially',
#  'adaptive framework cost epidemiological interventions statistical epidemic trajectory misspecification schedule iteratively interventionsbackground classic robustness',
#  'mods angiopoietin mechanisms target signal inflammation despite underlie systems unanswered immunoparesis haemodynamics debt pancreatitis intersection haemorrhage electrolyte certainly',
#  'neuraminidase flu drug treatment swine mutations antibody sitesin sandor pongor peramivir aravind zanamivir tamiflu relenza',
#  'ahv pcr assay mgb anatid taqman real herpesvirus fluorescent sensitivity wide time simplicity geese',
#  'protease viral mutants replication amino transcriptase hiv two immunodeficiency activity residues acids mutations drug protein stabilityreverse lend dimers critical',
#  'cvtree server phylogenetic genomes web whole update alignment tree genome implementation platform composition users database sequence free new upload tlife',
#  'glioblastoma lentiviral vectors pseudotyped therapeutic tumors gene therapy invasive glioma gammaretroviral stem suicide animal transduce egfp remission inefficient model human glycoprotein tumor cancer feature vivo thymidine spheroids prodrug',
#  'array hav strain oligonucleotide biotin represent plot base identification intensity amplify hybridization label pcr virus every products',
#  'ebv agents sclerosis childhood onset infectious framework epidemiological pathways disturb deficit biography prime biologic may aetiology multiple early',
#  'hrv strain utr subspecies recombination diversity children respiratory sequence hrvs rhinoviruses acute region comparative species fragment diagnose clinical least infect two characterize',
#  'cmv ill critically patients infection days immunocompetent icu outcomes cytomegalovirus ventilation mechanical meaningful reviewintroduction',
#  'heliox ventilation respiratory resistance expiratory minutes trap system mechanical gas air interval eit decrease rsv syncytial measurements volume oxygenation infants enrol',
#  'cox drak crc apoptosis kinase colorectal induce tumours hca cyclooxygenase qrt regulation vitro selective inhibitor administration',
#  'hpev substitutions estimate parechoviruses hpevs timescale evolutionary circulate ancestor evolution lineages synonymous capsid per structural regions rat timebackground reclassify phylogenetics',
#  'iras monoclonal hiras antibodies terminal protein reagents punctate opioid nusa morphine immunocytometry immunoblotting imidazoline hek clonidine bousquet',
#  'drug quinoline chloroquine malarial malaria progress resistant resistance additional witness pfcrt catabolize',
#  'poultry rural handle avian knowledge villagers',
#  'bird mediterranean movements western wetlandswild wetlands stopover dispersion birdborne species migratory',
#  'hemolytic anemia autoimmune therapy steroid rituximab severe immunosuppressive month dose patient taper rrituximab refractory remission extracorporeal days case oxygenation sustain prolong administer must weeks months treatment day',
#  'ire ridd nuclease xbp decay stress messenger splice mrnas variant encode activate regulate protein multitiered melanogaster cellsmaintenance',
#  'sequence relationship intra representation pyrimidine purine dna representations character intron graphical base distribution scale characteristics conserve differences provide undescribed sequencesdna',
#  'accept willingness pre alert pandemic vaccination healthcare workers influenza kong hong authority escalation level intention nurse phase questionnaires hospital vaccine medicine',
#  'interactions herpesvirus conserve vzv interactomes kshv protein able hsv interaction species systematically networksherpesviruses kbp intraviral herpesviral previously subfamilies orthologous',
#  'kawasaki ace frequencies polymorphism group dilatations genotype allelic cardiomyopathy coronary gene',
#  'hpiv virulence erk factor grb egf epidermal mapk interferon growth stat type airway signal cellular protein explain block response pathway pathogenesis',
#  'gmp cytosolic sense cyclic induce messenger cells nucleic compound widely second novel host pathway innate pathways bacterial via produce',
#  'secretase genes transcription activity alzheimer function wnt affect cancer substrates gene molecular reveal validate cluster map biological upp transcriptionally tera sharpen ptprg icds fatigo dvl cortices amn',
#  'bayesian inference spatial phylogeographic phylogeography dispersal diffusion geographical dynamics software temporal endemic sample framework enable model epidemic rootsas priors biogeogeography genetic pattern parsimony parsimonious localities inferences',
#  'mrep model repository disease midas warehouse table versions relational house version infectious access',
#  'escape nab env subject subtype drive autologous early domain antibodies hiv infection multiple change neutralize pathway pathways two time portrayal pathwaysone oscillate chimeras weaknesses cooperation glycan',
#  'kinase gne domain dimer crystal plugin myopathy mutations structure enhance text web protein version enzyme article structural udp subdomain sialurea rok recessive oligomer',
#  'diversity prevalence species nombre disease sin dilution hantavirus increase ecological decrease zoonotic',
#  'pedv outbreaks thailand diarrhea porcine',
#  'optimism pessimism women pregnant life quality across country score vitality lot ghanaian ghana pessimistic optimistic sample least health variables match unite measure',
#  'rabies test diagnosis countries molecular diagnostic develop biology clinical century barriers accept challenge nature conventional techniques benefit development use rapid unaffordable turnaround logistical expectation centurythe antemortem twin insurmountable',
#  'duck viruses influenza spread species trojan horse wild asian poultry subtypes sign maintain unresolved surreptitious',
#  'tbev tick encephalitis strain virion deficient adaptation siberian hemagglutinate ixodes feed atypical substitutions european europe virus genetically fatal fusion mutations emergence across appear surface ability westwards tickstick',
#  'lung nsclc drug hrct ild interstitial exclude illnesses involvement alternative cancer clinical symptoms associate',
#  'pbc udca biliary bile liver pathogenetic cirrhosis may patients transplantation progressive women aspects medical additional serum therapy therapeutic ursodeoxycholic pyruvate pruritus intrahepatic glutamyl florid fda enigmatic duct cirrhosisprimary',
#  'orma ldr rrna probe pair cyanobacteria set species milk contexts discrimination variations oligonucleotide applications sequence identification phylogenesis base',
#  'flu malaysia europe seasonal purchase pork malaysians europeans anxiety pandemic swine respondents prostitute preparatory homeless goods friends responses group initial particular underestimate regional intend mask perceive travel',
#  'cas biosystems adaptive',
#  'hhv recipients transplant graft stem allogeneic detectable herpesvirus transplantation load sample plasma fever antibodies days cell hscts hsct hemopoietic',
#  'ibv eat cells epithelial basal tracheal bronchitis chicken amplification avian culture virushere',
#  'cat fiv populations population males factor risk females sex density stochastic model dynamic explain prevalence finally ratio simple effect individuals',
#  'primer multiplex set software mpp mers primers sequence amplify algorithm prediction diverse virus',
#  'ifn shrnas shrna activation transduction lentiviral trigger intracellularly vector hairpin sirna avoid rnas short gene interferon pathway promoters immunostimulation compositional',
#  'delivery systems traffic nucleic cargo cationic easy biological oligonucleotides handle represent acid side reporter uptake intracellular peptide efficacy quantitative discuss overall systemscellular',
#  'pam vsa csa dbl var react ies monoclonal antigens falciparum immunity pregnancy naturally intact variant igg malaria domains',
#  'behavioral anxiety media perception behavior epidemic vis flu swine respondents uncertainty coverage april mediate threat social widespread distance novel concern response vary virus protective outbreak',
#  'stochastic manifold noise seir solution reduce population center model consider projection modelswe langevin relaxation infinite',
#  'distance minkowski metric road travel spatial analytical euclidean model measurements metrics estimate catheterization optimize residence approximate implement cardiac time service',
#  'decontamination ffrs filter ffr vhp oven bleach respirator respirators irradiation gas methods uvgi penetration niosh microwave facepiece eto ethylene decontaminate certify airflow dry aerosol',
#  'rivularis ciliata extract activity bergenia astilbe hsv herpes plant traditional',
#  'students norms tpb dental intention hiv subjective moral behavioural attitudes behaviour care perceive tanzanian sudanese sudan ssa intentions tanzania aid across variance medical control',
#  'receptors ali prr nacht lrr pattern pamps damp prrs trauma toll clinically like acute recognition molecules damage distress recognize innate',
#  'felv cat provirus dose infection seroconversion low focma proviral abortive positivity feline exposure persistent marrow bone load infect negative antigen tissue',
#  'peptidases substrates merops cleavages peptidase cleavage conserve physiological database site internet reason substrate collection synthetic poorly position proteins number inhibitors useful url polyproteins',
#  'rsps dengue prm subviral prme native secretion hela serotypes particles assembly rsp proteins supernatant efficient recombinant maturation produce cell undergo envelope use',
#  'wave case epidemic delay defer would prophylactic antivirals early treatment peak second novel contact step still phase control model nonimmune fraser strategies impact',
#  'termination reinitiation mnv uaa codon orf aug translation upstream stop mrna norovirus rrna motif murine expression upon efficient site reintiation',
#  'stem unfold hairpin upper bulge unstable translocation lower ribosome readily frameshifting loop nucleotide mechanical hiv tweezers toeprinting ribosomeribosomal',
#  'outdoor pathogens environments air work research future airpath airare human wider london concise',
#  'strategies combination pharmaceutical model individual pandemic reduce global restriction antiviral quarantine study travel stochastic influenza attack eight effectiveness social six distance delay',
#  'ipd wintertime seasonality philadelphia index effect strata pneumococcal climate radiation weekly disease occurrence associations invasive highest temperature risk regression environmental day incidence case exposure pneumonia increase urgency tertile sulphur stratum',
#  'autophagy llo monocytogenes bmdms atg gfp induce escape listeriolysin cytolysin lipidation listeria infection primary sufficient mutant intracellular consistent type whereas',
#  'mafa haplotypes alleles pedigreed cynomolgus mhc macaques definition cohort number complex unreported macaque lexicon indonesian discriminative segregate generations malaysian',
#  'hts parametric format cytotoxicity implementation assay multi throughput test well discuss testament screeningin handful',
#  'cyclosporine macrophage syndrome relapse activate weeks still treatment girl patient case disease follow fever old year two readmitted',
#  'abscesses acinetobacter lung community multiple acquire infections case patient reportacinetobacter presence underline sore malaise due',
#  'mkp mapk bcg tnf phosphatase mycobacterial kinase mtb mitogen pivotal mycobacterium monocytes erk expression regulate induction activate since',
# ...
#  'microglia activate phenotypes homeostasis release diverse cytokines since inflammatory rio phagocytose neurotrophins inflame hortega diseaseit crosstalk microglial eventual debris',
#  'typhimurium salmonella buffalo isolate calve water serovars spp characterize different gastroenteritis phage strain virulotypes muenster cryptosporidium virulence three rotavirus exhibit collect intestinal lesions severe lethal characterization prevalence',
#  'malaria syndromes childhood plasma proteome sma pattern severe proteomic children clinical pathogenesis define therefore profilesbackground ibadan holoendemic',
#  'structure dotknot prediction rna uwa csse edu pseudoknots pseudoknot supplementary comparative computational elements secondary sequencesmotivation',
#  'htt horizontal transfer events transposon detection life predictions eukaryotic bias cycle rat discuss transposable tes perspectivesthe overestimation nonspecialists explanations eukarya alike',
#  'lyc lnes lycorine nano oleic emulsions lipid uncoated mannosylated lipophilicity ionic entrapment tumor formulation acid',
#  'pandemic chile gradient climatic regions southern geographical school demographic influenza latitudinal onset reproduction connectivity peak vacation activity lag humidity estimate pattern south north maximum time',
#  'gateway multisite cerevisiae vectors destination saccharomyces clone accessible tag promoter assembly fragment yeast three widely technology biology epitope',
#  'cdv dog slam traits strain specialist generalist distemper carnivore express fitness canine environments value pleiotropy off lion carnivores cells homogeneous antagonistic trade',
#  'ptx net pentraxin neutrophil microbial sepsis certain store proteins inflammatory complex neutrophils anti extracellular localize marker component circulate detail diagnostic innate role',
#  'sgp ebov subversion antigenic ebola immunize host evasion antibodies anti secrete glycoprotein antibody virusin immunity mechanism mice vaccinology isoform',
#  'techniques amplification nucleic acid clinical virology laboratory opportunities care assay introduction technology chain reaction polymerase main currently patient',
#  'zone patients consolidation lung icu abnormality image two document admit involve swine infection initial five lower reticulation radiography peribronchovascular multifocal study',
#  'entry endosome acidification retroviruses retrovirus cathepsin endocytosis retroviral endosomes dependent think cell host pathways proteasesretroviruses hivs complicatedly',
#  'hcv rvv hepatitis nonstructural mice immunization liver vaccinia protein encode chronic proteins injection pathological suppress level virus mouse recombinant therapeutic inflammatory polyinosinic',
#  'nef partner interaction membrane screen hiv hereby gpm identify proteins hybrid protein nucleus yeast interactions vsig tspan tcblr subfraction proteinshiv pmepa',
#  'pertussis household infants korea infant vaccination transmission young months immunization source contact tdap lymphocytosis koreaa dtap resurgence booster age',
#  'lofreq sequence variants datasets population heterogeneity rare call throughput bacterial exist sourceforge sequenom gastric fluidigm exome executables datasetsthe caller',
#  'buho foci sgs pbs stress matlab image script throughput repress formation process manually granules aggregate silence automate mrnas cellular reliable body experiment mammalian proteins mrna upon analysis term',
#  'spp sargassum polysaccharides pallidum newcastle bronchitis adjuvant chickens lymphocyte inactivate',
#  'india inequalities disparities pandemic health source influenza plausible declare level geographic social access preparedness plan factor world model unequal',
#  'phylodynamic abc model bayesian summaries epochal antigenic data computation incidence approximate ecological evolution spatial fit influenza hemagglutinin evolutionary parameters feature long surveillance estimate key versatility',
#  'tmv phenanthroquinolizidine alkaloids configuration activity antiviral tobacco mosaic introduction compound vivo stucture phenanthroquinolizidines',
#  'antibody responses neutralize cell influenza expansion monovalent vaccines pdm vaccine subtype cells relationship pandemic response vaccination vaccinebackground',
#  'households quarantine leave pay parent work take access compliance school time financial lose resident recommendations',
#  'condom hiv men sex interventions msm chinese self receipt aor prevalence increase trend partner',
#  'tnf lta polymorphisms genotype ccl infection pandemic case severity influenza patients associate level virus control association illness contribute severer phosphokinase familial urea',
#  'patent complement relate trend compound immune interest discovery trademark macular innateimmunity chapter diagnosis research office intellectual immunoassays grant various rejection publication pathologies',
#  'clone scfvs clade phage selection hiv ebv antigen antibodies reactivity technology peptides scfv transformation hybridoma strategy library anti avoid dna neutralization positive variable elisa bind generation',
#  'hygiene wear mask face practice behaviors public season avoid japanese influenza personal gargle positive crowd wash occasional health occasionally',
#  'faecium swiv probiotic mdbk enterococcus cells swine defence viability influenza treat min propagation food medium porcine inhibitory virus health growth line direct',
#  'cells cell persistence viral mcmv hcv hiv regulate rheostats anti lcmv exhaustion infections killer mice virus mediate pathology act infect natural',
#  'influenza admissions intensive excess care seasonal aboriginal icu estimate people pregnant australia use women wales rate series pandemic epidemic pdm',
#  'aav upr perk scaav fold ire pathways vectors transfer modest activate gene unfold cellular mediate induce stress response inhibition activation vectorsthe metformin endoribonuclease vitro',
#  'hypoxia metastasis hif regulate metastatic genes target induce tumor molecules factor microenvironmental metastasishypoxia',
#  'keratitis herpetic therapy gene ocular hsv discuss therapeutic therapyocular neovascularization inherit cornea clip strategies research blindness assess reality',
#  'canadian communities research health aboriginal face workshop community populations indigenous pandemic collaborative objectives build challenge practice outcomes address',
#  'sbv lamb nss tropism vacuolation schmallenberg abort virus virulence calve experimental cerebral pathogenesis neurons naturally synthetic replicate biology system develop wild culture cell useful stillborn porencephaly passage',
#  'cavernous uterus partum myometrium hemangiomas hemangioma woman thrombi case vascular post myometrial gravid examination thrombosis fresh cesarean endothelium histological pulmonary section report rare hemorrhagic fatal delivery respiratory transabdominal thrombose thromboplastin thromboemboli spongy prothrombin',
#  'codon usage iav bias strain pandemic adaptation composition trna pdm mutational comprehensive pressure host selection virus different influenza orthomyxoviridae developmentbackground coa base suggest thr revisit',
#  'lrti hospitalizations pediatric lrtis infants bed year care age burden healthcare acute columbia respectively projections british due olds prevention november demand',
#  'apmv cleavage pathogenicity chickens site mutant duck replication old paramyxoviruses avirulent syncytium protein parental recovery vitro week confer recover increase',
#  'pacific territories island countries pandemic influenza august case confirm surveillance tokelau pitcairn picts email report gather outbreak illness institute regional like health despite world tuvalu niue maritime',
#  'childhood queensland orchid diary cohort ethics gastrointestinal birth hospital illness observational child research age swab dynamic women epidemiology infectious study diseases incidence respiratory children pathogens',
#  'getah virus vidiscr rapd cdna strain isolate discovery polymorphic novel gene amplify method random sequence structural identification protein togaviridae',
#  'mzp cap rna hce guanylyltransferase monophosphate mizoribine inhibitor mrnas inhibit triphosphatase impdh guanine novo catalyze impair activity agent nucleotide',
#  'vocs exhale pulmonary diseases volatile organic copd clinical profile asthma accurately patients compound systematic diagnose disease tract study techniques cancer healthy control apply',
#  'gbv hiv disulfide peptides loop entry fusion coinfection terminus interfere bind experiment glycoprotein viraemia niche loopa imitation coreceptor termini partly flaviviridae engagement',
#  'brain proteobacteria bacterial hiv odc microbial sequence rrna surg implantation rag group quantity white matter cerebral rna diversity human immune detect aid host profile variably',
#  'dpi pig saa app swine serum significantly score acute concentration influenza swh pasteurella haptoglobin piglets coinfected amyloid crp severity phase antibodies reactive protein',
#  'drip positional epitopes bias source towards class antigens skew mhc terminus viral products degree restrict peptides constitutive conservationthe',
#  'caspase bioenergetics lung tissue amc atp activity wistar oxygenate mem asp incubate buffer toxins min cleave content cellular despite monitor rat pathogens urethane',
#  'ibv chickens lesions republic china bronchitis virulent isolate kidney severe deaths day people old',
#  'mbds mekong trust network surveillance basin countries threats border health professionals disease across pioneer minister memorandum jointly emulate yunnan',
#  'quarantine centuries public diseases become strategy globalize millennium cornerstone reemerging plague socioeconomic careful infectious',
#  'sequencers information global technologies laboratories genome public share generation health clinical provide spawn responsethe modernize advancement quicker',
#  'hbov saudi bocavirus arabia children detect tract genotype infections respiratory circulate patients',
#  'hiv apoptosis sign activation ask sensitize ligation immune serum excessive accelerate individuals depletion mechanism pro dendritic undergo induce aid envelope circulate chronic death become prevent',
#  'tii cells lps alveolar culture tnf response facs rat epithelium type primary lung stimulation macrophages immune prior level report increase stimulationthe blunt',
#  'tunnel polymerase structure segment ntp sequence polymerases exterior structural template species residue though rna composition entry residues map conserve',
#  'pcd beat ciliary patients qualitative quantitative gold evaluation standard diagnosis analysis pattern parameters nasal suspect videomicroscopy inconclusive edge dyskinesia concordant ciliated nitric',
#  'age mortality breakpoints pandemic excess kentucky years minimum rat sex maximum risk unknown year statewide kentuckybackground',
#  'membrane reconstitution proteins model phospholipid reconstitute activities activity protein retain composition often better discuss systems nanodiscs bilayers',
#  'rvsv rabv transsynaptic retrograde anterograde vsv tracer neuron connections rabies stomatitis recombinant neurons vesicular trace virus provide',
#  'ali patients pneumonia inappropriate nest risk development antimicrobial hospitalize infectious acute injury initial factor predict pathogen rochester prehospital pneumonias pneumoniaintroduction microbiologically',
#  'hcv lfia das strip new anti sandwich serum immunoassay antibodies lateral sera elisa double flow plasma',
#  'hcv curcumin oxygenase heme inhibit akt erk induction dependently replication inhibition protein dose expression activities hepatitis hemin aktalthough anti replicon',
#  'travel restriction land air restrictions sea transport kong hong pandemic mitigation antivirals hospitalization strategies model influenza china peak source new establish regulate virusbackground retard intrusive arrivals allow',
#  'versus unsuspected influenza patients respiratory icu icus systematically median radiograph sample failure screen days lower chest infiltrate stay localize suspect',
#  'registry icus flu french icu university burden geographical line screen daily cohort occupancy areas exceed bed threshold infect hospitals participate weeks poorly',
#  'pneumococcal icu patients pneumoniae cap pneumonia replacement renal admit penicillin mortality severe outcome therapy septic adequate reach shock susceptibility acquire failure two bacteraemia antibiotherapy thoracic',
#  'synthetic genomics biology organisms applications biological new engineer function genomes benefit exist systems stir satisfy renewable progressively',
#  'codon bias usage dinucleotide composition content rna pressure mutational mononucleotide viruses nucleotide genomic synonymous explain translation position relative',
#  'renal postoperative mortality transplant liver failure rrt replacement recipients preoperative group acute therapy cumulative baseline icu',
#  'mineral oil bioaerosol andersen agar impactor bounce min sample aerosols particle plate biostage impaction samplers opc impactors enhancements desiccation stage plat aerosolize',
#  'sari persons hospitalize kenya guatemala old influenza years per associate case healthcare provincial burden national severe countries base',
#  'hbz htlv tsp ham atl patients humoral antibody response zipper immune serum leucine infect responses subtype subject basic',
#  'qtl weight loss disease variation contribute identify genetic host induce influenza virus collaborative confound phenotypes replication aspects genetically observe environmental outcomes diverse inflammation pre populations correlate',
#  'asthma hospitalize patients icu likely admission influenza pneumonia among pdm persons die admit pandemic old case',
#  'ssrs genomes repeat genome size sequence certain virus distribute longer strongly simple variances sizebackground repetitiveness',
#  'pkr trna nucleoside modifications activation activate tertiary transcripts trnas phe native transcript suppress natively modify innate intrinsic ability bovine vitro cellular rna yeast',
#  'unresectable cryoablation sorafenib hcc median patients stage tolerability treat hepatocellular combine progression months advance',
#  'mtb cba secrete cells tuberculosis expansions mycobacterium immunosuppressive depletion although cell infection chronic vivo tim mice',
#  'polyethylenimine radiation tlr agonist dose irradiation pei survival body mediate receive agents effect toll anti weight correlation animal application',
#  'malarial disturbances infection immunological countries parasitic malaria immune associate drug urbanization overcrowd ordinate infectionmalaria due reemerging',
#  'vaccine determinants successful developmentepidemiological measurable requirement',
#  'rule classification syndromic automate interpretability macro performance micro class achieve learn laboratory bay classifier veterinary equal base experts tree decision algorithm high methods score',
#  'viral sequence sample rna ultra threats copy low full prior genomes amount independent agents complete amplificationrna',
#  'mimetics protein hairpin epitope design synthetic grow vaccinology outer antibiotics crystal biologically ligands motifs structure start inhibitors point membrane importance fold structural wiley sons',
#  'panad pan bonobo vector transgene adenovirus influenza antigens conserve vaccines antibody paniscusamong paniscus npm',
#  'weather extreme water events outbreaks waterborne promed relate flood report spp rainfall georef drought diseaseglobal alongside',
#  'kshv falciparum malaria syndemic cyto basigin mutual sarcoma kaposi adherence erythrocytes aggressive host invasion parasite endemic relationship implications infect interactions unexplored triangulation pathobiological parasitemia neoplasm merozoites',
#  'nols nucleolus nucleolar noa localization direct capable egfp three residues mammalian cluster sequence conserve amino protein']

# %%
docs['keywords'] = results # Adding keywords column to the dataframe

# %%
docs.head(3)
# Out:
#    cord_uid                                       sha source_x  \
# 0  ug7v899j  d1aafb70c066a2068b02786f8929fd9c900897fb      PMC
# 1  02tnwd4m  6b0567729c2143a66d737eb0a2f63f2dce2e5a7d      PMC
# 2  ejv2xln0  06ced00a5fc04215949aa72528f2eeaae1d58927      PMC
#
#                                                title                    doi  \
# 0  Clinical features of culture-proven Mycoplasma...  10.1186/1471-2334-1-6
# 1  Nitric oxide: a pro-inflammatory mediator in l...           10.1186/rr14
# 2    Surfactant protein-D and pulmonary host defense           10.1186/rr19
#
#       pmcid pubmed_id license  \
# 0  PMC35282  11472636   no-cc
# 1  PMC59543  11667967   no-cc
# 2  PMC59549  11667972   no-cc
#
#                                             abstract publish_time  \
# 0  OBJECTIVE: This retrospective chart review des...   2001-07-04
# 1  Inflammatory diseases of the respiratory tract...   2000-08-15
# 2  Surfactant protein-D (SP-D) participates in th...   2000-08-25
#
#                                              authors         journal  \
# 0                Madani, Tariq A; Al-Ghamdi, Aisha A  BMC Infect Dis
# 1  Vliet, Albert van der; Eiserich, Jason P; Cros...      Respir Res
# 2                                    Crouch, Erika C      Respir Res
#
#                                       pdf_json_files  \
# 0  document_parses/pdf_json/d1aafb70c066a2068b027...
# 1  document_parses/pdf_json/6b0567729c2143a66d737...
# 2  document_parses/pdf_json/06ced00a5fc04215949aa...
#
#                                pmc_json_files  \
# 0  document_parses/pmc_json/PMC35282.xml.json
# 1  document_parses/pmc_json/PMC59543.xml.json
# 2  document_parses/pmc_json/PMC59549.xml.json
#
#                                                  url  \
# 0  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...
# 1  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 2  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
#
#                                                 text  \
# 0  clinical feature culture prove mycoplasma pneu...
# 1  nitric oxide pro inflammatory mediator lung di...
# 2  surfactant protein pulmonary host defensesurfa...
#
#                                             keywords
# 0  pneumoniae patients comorbidities pneumonia co...
# 1  inflammatory oxidant presume nitric oxide cont...
# 2  surfactant deficient glycoconjugates organic l...

# %%
docs.drop(columns='text',inplace=True) 
# Dropping text column from dataframe as we already selected keywords and added them to datframe

# %%
docs.columns
# Out:
# Index(['cord_uid', 'sha', 'source_x', 'title', 'doi', 'pmcid', 'pubmed_id',
#        'license', 'abstract', 'publish_time', 'authors', 'journal',
#        'pdf_json_files', 'pmc_json_files', 'url', 'keywords'],
#       dtype='object')

# %%
# Converting docs dataframe to csv file for indexing
docs.to_csv("keywords_added_docs.csv",index=False)

# %%
# This file is indexed using Logstash
